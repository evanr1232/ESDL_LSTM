# %%
import os
import ipyparallel as ipp
import time
import pickle


from neuralhydrology.utils.config import Config

from neuralhydrology.nh_run import ESDL_start_run, eval_run
from pathlib import Path
import xarray as xr
from neuralhydrology.utils.nh_results_ensemble import create_results_ensemble

# %%
os.getcwd()
# Out:
# '/global/home/groups/pc_dsdisc/ESDL/ESDL_LSTM/neuralhydrology'

# %%
mycluster = ipp.Cluster(n=int(os.getenv('SLURM_CPUS_ON_NODE')))
c = mycluster.start_and_connect_sync()
dview = c[:]
dview.block = True   
dview.apply(lambda : "Hello, World")
# Out:
# Starting 32 engines with <class 'ipyparallel.cluster.launcher.LocalEngineSetLauncher'>
# 100%|██████████| 32/32 [00:05<00:00,  5.57engine/s]
# ['Hello, World',
#  'Hello, World',
#  'Hello, World',
#  'Hello, World',
#  'Hello, World',
#  'Hello, World',
#  'Hello, World',
#  'Hello, World',
#  'Hello, World',
#  'Hello, World',
#  'Hello, World',
#  'Hello, World',
#  'Hello, World',
#  'Hello, World',
#  'Hello, World',
#  'Hello, World',
#  'Hello, World',
#  'Hello, World',
#  'Hello, World',
#  'Hello, World',
#  'Hello, World',
#  'Hello, World',
#  'Hello, World',
#  'Hello, World',
#  'Hello, World',
#  'Hello, World',
#  'Hello, World',
#  'Hello, World',
#  'Hello, World',
#  'Hello, World',
#  'Hello, World',
#  'Hello, World']

# %%
len(c.ids)
# Out:
# 32

# %%
# hidden_states = [64, 96, 156, 196, 256]
# dropout_rate = [0.0, 0.25, 0.4, 0.5]
# input_seq_lengths = [90, 180, 270, 365]
#stacked_layers = [1, 2]

hidden_states = range(63, 63+len(c.ids))
dropout_rate = [0.5]
input_seq_lengths = [90]


param_combos = []
for i in hidden_states:
    for j in dropout_rate:
        for k in input_seq_lengths:
            param_combos.append((i, j, k))

# %%
len(param_combos)
# Out:
# 32

# %%
def ESDL_ensemble(params):
    '''Train ensemble for given config file and return ensemble NSE'''
    num_ensemble_members=1
    
    #copy data 24 times, each worker calls a different one
    
    config_path = Path("../initial_exploration/parallel_grid_search.yml") #read this in once, pass in object to all workers
    config = Config(config_path)
    config.update_config({'epochs': 5})
    config.update_config({'hidden_size': params[0]})
    config.update_config({'output_dropout': params[1]})
    config.update_config({'seq_length': params[2]})
    
    output_path = 'parallel_grid_search_test' + str(params[0]) + '_' + str(params[1]) + '_' + str(params[2])
    config.update_config({'experiment_name': output_path})
    
    #train num_ensemble_members models
    paths = [] #store the path of the results of the model
    for i in range(num_ensemble_members):
        ESDL_start_run(config, gpu=-1)
        path = config.run_dir
        paths.append(path)
    
    #evaluate models
    for p in paths:
        eval_run(run_dir=p, period="test")
        eval_run(run_dir=p, period="validation")
        with open(p / "test" / "model_epoch005" / "test_results.p", "rb") as fp: #comment next three lines out when using more than one ensemble member
            results = pickle.load(fp)
            ensemble_nse = results['Tuler']['1D']['NSE'] 

    # ensemble_run = create_results_ensemble(paths, period='validation')
    # ensemble_nse = ensemble_run['Tuler']['1D']['NSE']
    return (params, ensemble_nse)

# %%
# push imports to workers

dview.execute('from neuralhydrology.utils.config import Config')
dview.execute('from neuralhydrology.nh_run import ESDL_start_run, eval_run')
dview.execute('from neuralhydrology.nh_run import ESDL_start_run, eval_run')
dview.execute('from pathlib import Path')
dview.execute('import xarray as xr')
dview.execute('from neuralhydrology.utils.nh_results_ensemble import create_results_ensemble')
dview.execute('import pickle')

# %%
lview = c.load_balanced_view()
# Cause execution on main process to wait while tasks sent to workers finish
lview.block = True

# %%
# in parallel

start_time = time.time()

all_nse = lview.map(ESDL_ensemble, param_combos) # map each param combo to the ESDL_ensemble fn, where they run in parallel
end_time = time.time()

elapsed_time = end_time - start_time
print("Elapsed time:", elapsed_time, "seconds")

# %%
all_nse
# Out:
# [((63, 0.5, 90), 0.640073150396347),
#  ((64, 0.5, 90), 0.6261449456214905),
#  ((65, 0.5, 90), 0.623724639415741),
#  ((66, 0.5, 90), 0.668786495923996),
#  ((67, 0.5, 90), 0.6115140318870544),
#  ((68, 0.5, 90), 0.6680737435817719),
#  ((69, 0.5, 90), 0.6114262342453003),
#  ((70, 0.5, 90), 0.5818195939064026),
#  ((71, 0.5, 90), 0.6156918704509735),
#  ((72, 0.5, 90), 0.6414744555950165),
#  ((73, 0.5, 90), 0.5829590857028961),
#  ((74, 0.5, 90), 0.5853991806507111),
#  ((75, 0.5, 90), 0.606875866651535),
#  ((76, 0.5, 90), 0.5530081391334534),
#  ((77, 0.5, 90), 0.5351739823818207),
#  ((78, 0.5, 90), 0.6493227481842041),
#  ((79, 0.5, 90), 0.59109827876091),
#  ((80, 0.5, 90), 0.6361516714096069),
#  ((81, 0.5, 90), 0.6096990704536438),
#  ((82, 0.5, 90), 0.5568223297595978),
#  ((83, 0.5, 90), 0.5860029757022858),
#  ((84, 0.5, 90), 0.591246634721756),
#  ((85, 0.5, 90), 0.5354208946228027),
#  ((86, 0.5, 90), 0.5735471546649933),
#  ((87, 0.5, 90), 0.6563299000263214),
#  ((88, 0.5, 90), 0.5440194308757782),
#  ((89, 0.5, 90), 0.5761094987392426),
#  ((90, 0.5, 90), 0.5476375222206116),
#  ((91, 0.5, 90), 0.6719977259635925),
#  ((92, 0.5, 90), 0.6121598780155182),
#  ((93, 0.5, 90), 0.583870142698288),
#  ((94, 0.5, 90), 0.5497769415378571)]

# %%
#in series
all_nse = []
start_time = time.time()

for i in param_combos:
    all_nse.append(ESDL_ensemble(i))

end_time = time.time()
elapsed_time = end_time - start_time
print("Elapsed time:", elapsed_time, "seconds")
# Out:
# 2024-09-29 13:58:43,763: Logging to /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test63_0.5_90_2909_135843/output.log initialized.
# 2024-09-29 13:58:43,764: ### Folder structure created at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test63_0.5_90_2909_135843
# 2024-09-29 13:58:43,764: ### Run configurations for parallel_grid_search_test63_0.5_90
# 2024-09-29 13:58:43,764: data_dir: /global/scratch/users/evanrobert
# 2024-09-29 13:58:43,765: experiment_name: parallel_grid_search_test63_0.5_90
# 2024-09-29 13:58:43,765: run_dir: /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test63_0.5_90_2909_135843
# 2024-09-29 13:58:43,766: train_basin_file: ../initial_exploration/exploration_tuler
# 2024-09-29 13:58:43,766: validation_basin_file: ../initial_exploration/exploration_tuler
# 2024-09-29 13:58:43,766: test_basin_file: ../initial_exploration/exploration_tuler
# 2024-09-29 13:58:43,767: train_start_date: 1981-10-01 00:00:00
# 2024-09-29 13:58:43,767: train_end_date: 1997-09-30 00:00:00
# 2024-09-29 13:58:43,767: validation_start_date: 1997-10-01 00:00:00
# 2024-09-29 13:58:43,768: validation_end_date: 2000-09-30 00:00:00
# 2024-09-29 13:58:43,768: test_start_date: 2000-10-01 00:00:00
# 2024-09-29 13:58:43,768: test_end_date: 2005-09-30 00:00:00
# 2024-09-29 13:58:43,769: device: cpu
# 2024-09-29 13:58:43,769: validate_every: 5
# 2024-09-29 13:58:43,769: validate_n_random_basins: 1
# 2024-09-29 13:58:43,769: metrics: ['NSE', 'MSE']
# 2024-09-29 13:58:43,770: model: cudalstm
# 2024-09-29 13:58:43,770: head: regression
# 2024-09-29 13:58:43,770: output_activation: linear
# 2024-09-29 13:58:43,771: hidden_size: 63
# 2024-09-29 13:58:43,771: initial_forget_bias: 3
# 2024-09-29 13:58:43,771: output_dropout: 0.5
# 2024-09-29 13:58:43,772: optimizer: Adam
# 2024-09-29 13:58:43,772: loss: MSE
# 2024-09-29 13:58:43,772: learning_rate: {0: 0.01, 30: 0.005, 40: 0.001}
# 2024-09-29 13:58:43,772: batch_size: 256
# 2024-09-29 13:58:43,773: epochs: 5
# 2024-09-29 13:58:43,773: clip_gradient_norm: 1
# 2024-09-29 13:58:43,773: predict_last_n: 1
# 2024-09-29 13:58:43,774: seq_length: 90
# 2024-09-29 13:58:43,774: num_workers: 1
# 2024-09-29 13:58:43,774: log_interval: 5
# 2024-09-29 13:58:43,774: log_tensorboard: True
# 2024-09-29 13:58:43,775: log_n_figures: 1
# 2024-09-29 13:58:43,775: save_weights_every: 1
# 2024-09-29 13:58:43,775: dataset: usace
# 2024-09-29 13:58:43,776: dynamic_inputs: ['MF_TuleR_S10ET-POTENTIAL', 'MF_TuleR_S10FLOW', 'MF_TuleR_S10PRECIP-INC', 'MF_TuleR_S10SATURATION FRACTION', 'MF_TuleR_S10STORAGE-SOIL', 'MF_TuleR_S10SWE-OBSERVED', 'MF_TuleR_S10TEMPERATURE-AIR', 'MF_TuleR_S20ET-POTENTIAL', 'MF_TuleR_S20FLOW', 'MF_TuleR_S20PRECIP-INC', 'MF_TuleR_S20SATURATION FRACTION', 'MF_TuleR_S20STORAGE-SOIL', 'MF_TuleR_S20SWE-OBSERVED', 'MF_TuleR_S20TEMPERATURE-AIR', 'NF_TuleR_S10ET-POTENTIAL', 'NF_TuleR_S10FLOW', 'NF_TuleR_S10PRECIP-INC', 'NF_TuleR_S10SATURATION FRACTION', 'NF_TuleR_S10STORAGE-SOIL', 'NF_TuleR_S10SWE-OBSERVED', 'NF_TuleR_S10TEMPERATURE-AIR', 'ReservoirInflowFLOW', 'SF_TuleR_S10ET-POTENTIAL', 'SF_TuleR_S10FLOW', 'SF_TuleR_S10PRECIP-INC', 'SF_TuleR_S10SATURATION FRACTION', 'SF_TuleR_S10STORAGE-SOIL', 'SF_TuleR_S10SWE-OBSERVED', 'SF_TuleR_S10TEMPERATURE-AIR', 'TuleR_S10ET-POTENTIAL', 'TuleR_S10FLOW', 'TuleR_S10PRECIP-INC', 'TuleR_S10SATURATION FRACTION', 'TuleR_S10STORAGE-SOIL', 'TuleR_S10TEMPERATURE-AIR', 'TuleR_S20ET-POTENTIAL', 'TuleR_S20FLOW', 'TuleR_S20PRECIP-INC', 'TuleR_S20SATURATION FRACTION', 'TuleR_S20STORAGE-SOIL', 'TuleR_S20SWE-OBSERVED', 'TuleR_S20TEMPERATURE-AIR']
# 2024-09-29 13:58:43,776: target_variables: ['ReservoirInflowFLOW-OBSERVED']
# 2024-09-29 13:58:43,776: number_of_basins: 1
# 2024-09-29 13:58:43,777: train_dir: /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test63_0.5_90_2909_135843/train_data
# 2024-09-29 13:58:43,777: img_log_dir: /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test63_0.5_90_2909_135843/img_log
# 2024-09-29 13:58:43,782: ### Device cpu will be used for training
# 2024-09-29 13:58:43,783: Loading basin data into xarray data set.
# 100%|██████████| 1/1 [00:00<00:00, 10.65it/s]
# 2024-09-29 13:58:43,905: Create lookup table and convert to pytorch tensor
# 100%|██████████| 1/1 [00:01<00:00,  1.62s/it]
# # Epoch 1: 100%|██████████| 23/23 [00:02<00:00,  9.93it/s, Loss: 0.0760]
# 2024-09-29 13:58:48,783: Epoch 1 average loss: avg_loss: 0.24608, avg_total_loss: 0.24608
# # Epoch 2: 100%|██████████| 23/23 [00:01<00:00, 11.61it/s, Loss: 0.0932]
# 2024-09-29 13:58:50,792: Epoch 2 average loss: avg_loss: 0.13811, avg_total_loss: 0.13811
# # Epoch 3: 100%|██████████| 23/23 [00:01<00:00, 11.57it/s, Loss: 0.1038]
# 2024-09-29 13:58:52,907: Epoch 3 average loss: avg_loss: 0.10768, avg_total_loss: 0.10768
# # Epoch 4: 100%|██████████| 23/23 [00:01<00:00, 11.70it/s, Loss: 0.0210]
# 2024-09-29 13:58:54,956: Epoch 4 average loss: avg_loss: 0.08845, avg_total_loss: 0.08845
# # Epoch 5: 100%|██████████| 23/23 [00:02<00:00, 11.34it/s, Loss: 0.0313]
# 2024-09-29 13:58:57,064: Epoch 5 average loss: avg_loss: 0.09280, avg_total_loss: 0.09280
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  1.92it/s]
# 2024-09-29 13:58:57,956: Epoch 5 average validation loss: 0.05909 -- Median validation metrics: avg_loss: 0.05909, NSE: 0.86565, MSE: 27864.48828
# 2024-09-29 13:58:57,994: Using the model weights from /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test63_0.5_90_2909_135843/model_epoch005.pt
# # Evaluation: 100%|██████████| 1/1 [00:00<00:00,  2.09it/s]
# 2024-09-29 13:58:58,490: Stored metrics at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test63_0.5_90_2909_135843/test/model_epoch005/test_metrics.csv
# 2024-09-29 13:58:58,493: Stored results at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test63_0.5_90_2909_135843/test/model_epoch005/test_results.p
# 2024-09-29 13:58:58,509: Using the model weights from /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test63_0.5_90_2909_135843/model_epoch005.pt
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  5.07it/s]
# 2024-09-29 13:58:58,714: Stored metrics at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test63_0.5_90_2909_135843/validation/model_epoch005/validation_metrics.csv
# 2024-09-29 13:58:58,716: Stored results at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test63_0.5_90_2909_135843/validation/model_epoch005/validation_results.p
# 2024-09-29 13:58:58,725: Logging to /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test64_0.5_90_2909_135858/output.log initialized.
# 2024-09-29 13:58:58,726: ### Folder structure created at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test64_0.5_90_2909_135858
# 2024-09-29 13:58:58,726: ### Run configurations for parallel_grid_search_test64_0.5_90
# 2024-09-29 13:58:58,726: data_dir: /global/scratch/users/evanrobert
# 2024-09-29 13:58:58,727: experiment_name: parallel_grid_search_test64_0.5_90
# 2024-09-29 13:58:58,727: run_dir: /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test64_0.5_90_2909_135858
# 2024-09-29 13:58:58,727: train_basin_file: ../initial_exploration/exploration_tuler
# 2024-09-29 13:58:58,727: validation_basin_file: ../initial_exploration/exploration_tuler
# 2024-09-29 13:58:58,728: test_basin_file: ../initial_exploration/exploration_tuler
# 2024-09-29 13:58:58,728: train_start_date: 1981-10-01 00:00:00
# 2024-09-29 13:58:58,728: train_end_date: 1997-09-30 00:00:00
# 2024-09-29 13:58:58,729: validation_start_date: 1997-10-01 00:00:00
# 2024-09-29 13:58:58,729: validation_end_date: 2000-09-30 00:00:00
# 2024-09-29 13:58:58,729: test_start_date: 2000-10-01 00:00:00
# 2024-09-29 13:58:58,729: test_end_date: 2005-09-30 00:00:00
# 2024-09-29 13:58:58,730: device: cpu
# 2024-09-29 13:58:58,730: validate_every: 5
# 2024-09-29 13:58:58,730: validate_n_random_basins: 1
# 2024-09-29 13:58:58,730: metrics: ['NSE', 'MSE']
# 2024-09-29 13:58:58,731: model: cudalstm
# 2024-09-29 13:58:58,731: head: regression
# 2024-09-29 13:58:58,731: output_activation: linear
# 2024-09-29 13:58:58,732: hidden_size: 64
# 2024-09-29 13:58:58,732: initial_forget_bias: 3
# 2024-09-29 13:58:58,732: output_dropout: 0.5
# 2024-09-29 13:58:58,732: optimizer: Adam
# 2024-09-29 13:58:58,733: loss: MSE
# 2024-09-29 13:58:58,733: learning_rate: {0: 0.01, 30: 0.005, 40: 0.001}
# 2024-09-29 13:58:58,733: batch_size: 256
# 2024-09-29 13:58:58,733: epochs: 5
# 2024-09-29 13:58:58,734: clip_gradient_norm: 1
# 2024-09-29 13:58:58,734: predict_last_n: 1
# 2024-09-29 13:58:58,734: seq_length: 90
# 2024-09-29 13:58:58,734: num_workers: 1
# 2024-09-29 13:58:58,735: log_interval: 5
# 2024-09-29 13:58:58,735: log_tensorboard: True
# 2024-09-29 13:58:58,735: log_n_figures: 1
# 2024-09-29 13:58:58,736: save_weights_every: 1
# 2024-09-29 13:58:58,736: dataset: usace
# 2024-09-29 13:58:58,736: dynamic_inputs: ['MF_TuleR_S10ET-POTENTIAL', 'MF_TuleR_S10FLOW', 'MF_TuleR_S10PRECIP-INC', 'MF_TuleR_S10SATURATION FRACTION', 'MF_TuleR_S10STORAGE-SOIL', 'MF_TuleR_S10SWE-OBSERVED', 'MF_TuleR_S10TEMPERATURE-AIR', 'MF_TuleR_S20ET-POTENTIAL', 'MF_TuleR_S20FLOW', 'MF_TuleR_S20PRECIP-INC', 'MF_TuleR_S20SATURATION FRACTION', 'MF_TuleR_S20STORAGE-SOIL', 'MF_TuleR_S20SWE-OBSERVED', 'MF_TuleR_S20TEMPERATURE-AIR', 'NF_TuleR_S10ET-POTENTIAL', 'NF_TuleR_S10FLOW', 'NF_TuleR_S10PRECIP-INC', 'NF_TuleR_S10SATURATION FRACTION', 'NF_TuleR_S10STORAGE-SOIL', 'NF_TuleR_S10SWE-OBSERVED', 'NF_TuleR_S10TEMPERATURE-AIR', 'ReservoirInflowFLOW', 'SF_TuleR_S10ET-POTENTIAL', 'SF_TuleR_S10FLOW', 'SF_TuleR_S10PRECIP-INC', 'SF_TuleR_S10SATURATION FRACTION', 'SF_TuleR_S10STORAGE-SOIL', 'SF_TuleR_S10SWE-OBSERVED', 'SF_TuleR_S10TEMPERATURE-AIR', 'TuleR_S10ET-POTENTIAL', 'TuleR_S10FLOW', 'TuleR_S10PRECIP-INC', 'TuleR_S10SATURATION FRACTION', 'TuleR_S10STORAGE-SOIL', 'TuleR_S10TEMPERATURE-AIR', 'TuleR_S20ET-POTENTIAL', 'TuleR_S20FLOW', 'TuleR_S20PRECIP-INC', 'TuleR_S20SATURATION FRACTION', 'TuleR_S20STORAGE-SOIL', 'TuleR_S20SWE-OBSERVED', 'TuleR_S20TEMPERATURE-AIR']
# 2024-09-29 13:58:58,736: target_variables: ['ReservoirInflowFLOW-OBSERVED']
# 2024-09-29 13:58:58,737: number_of_basins: 1
# 2024-09-29 13:58:58,737: train_dir: /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test64_0.5_90_2909_135858/train_data
# 2024-09-29 13:58:58,737: img_log_dir: /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test64_0.5_90_2909_135858/img_log
# 2024-09-29 13:58:58,740: ### Device cpu will be used for training
# 2024-09-29 13:58:58,741: Loading basin data into xarray data set.
# 100%|██████████| 1/1 [00:00<00:00, 13.40it/s]
# 2024-09-29 13:58:58,837: Create lookup table and convert to pytorch tensor
# 100%|██████████| 1/1 [00:00<00:00, 17.22it/s]
# # Epoch 1: 100%|██████████| 23/23 [00:01<00:00, 12.56it/s, Loss: 0.1810]
# 2024-09-29 13:59:00,795: Epoch 1 average loss: avg_loss: 0.25015, avg_total_loss: 0.25015
# # Epoch 2: 100%|██████████| 23/23 [00:01<00:00, 12.45it/s, Loss: 0.0367]
# 2024-09-29 13:59:02,709: Epoch 2 average loss: avg_loss: 0.13166, avg_total_loss: 0.13166
# # Epoch 3: 100%|██████████| 23/23 [00:01<00:00, 12.41it/s, Loss: 0.0323]
# 2024-09-29 13:59:04,635: Epoch 3 average loss: avg_loss: 0.10039, avg_total_loss: 0.10039
# # Epoch 4: 100%|██████████| 23/23 [00:01<00:00, 12.64it/s, Loss: 0.0469]
# 2024-09-29 13:59:06,538: Epoch 4 average loss: avg_loss: 0.09766, avg_total_loss: 0.09766
# # Epoch 5: 100%|██████████| 23/23 [00:01<00:00, 12.48it/s, Loss: 0.0383]
# 2024-09-29 13:59:08,419: Epoch 5 average loss: avg_loss: 0.09366, avg_total_loss: 0.09366
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  5.01it/s]
# 2024-09-29 13:59:08,949: Epoch 5 average validation loss: 0.04818 -- Median validation metrics: avg_loss: 0.04818, NSE: 0.89051, MSE: 22707.75195
# 2024-09-29 13:59:08,973: Using the model weights from /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test64_0.5_90_2909_135858/model_epoch005.pt
# # Evaluation: 100%|██████████| 1/1 [00:00<00:00,  4.04it/s]
# 2024-09-29 13:59:09,229: Stored metrics at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test64_0.5_90_2909_135858/test/model_epoch005/test_metrics.csv
# 2024-09-29 13:59:09,232: Stored results at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test64_0.5_90_2909_135858/test/model_epoch005/test_results.p
# 2024-09-29 13:59:09,248: Using the model weights from /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test64_0.5_90_2909_135858/model_epoch005.pt
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  5.43it/s]
# 2024-09-29 13:59:09,440: Stored metrics at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test64_0.5_90_2909_135858/validation/model_epoch005/validation_metrics.csv
# 2024-09-29 13:59:09,442: Stored results at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test64_0.5_90_2909_135858/validation/model_epoch005/validation_results.p
# 2024-09-29 13:59:09,451: Logging to /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test65_0.5_90_2909_135909/output.log initialized.
# 2024-09-29 13:59:09,452: ### Folder structure created at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test65_0.5_90_2909_135909
# 2024-09-29 13:59:09,452: ### Run configurations for parallel_grid_search_test65_0.5_90
# 2024-09-29 13:59:09,453: data_dir: /global/scratch/users/evanrobert
# 2024-09-29 13:59:09,453: experiment_name: parallel_grid_search_test65_0.5_90
# 2024-09-29 13:59:09,453: run_dir: /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test65_0.5_90_2909_135909
# 2024-09-29 13:59:09,453: train_basin_file: ../initial_exploration/exploration_tuler
# 2024-09-29 13:59:09,454: validation_basin_file: ../initial_exploration/exploration_tuler
# 2024-09-29 13:59:09,454: test_basin_file: ../initial_exploration/exploration_tuler
# 2024-09-29 13:59:09,454: train_start_date: 1981-10-01 00:00:00
# 2024-09-29 13:59:09,455: train_end_date: 1997-09-30 00:00:00
# 2024-09-29 13:59:09,455: validation_start_date: 1997-10-01 00:00:00
# 2024-09-29 13:59:09,455: validation_end_date: 2000-09-30 00:00:00
# 2024-09-29 13:59:09,455: test_start_date: 2000-10-01 00:00:00
# 2024-09-29 13:59:09,456: test_end_date: 2005-09-30 00:00:00
# 2024-09-29 13:59:09,456: device: cpu
# 2024-09-29 13:59:09,456: validate_every: 5
# 2024-09-29 13:59:09,456: validate_n_random_basins: 1
# 2024-09-29 13:59:09,457: metrics: ['NSE', 'MSE']
# 2024-09-29 13:59:09,457: model: cudalstm
# 2024-09-29 13:59:09,457: head: regression
# 2024-09-29 13:59:09,457: output_activation: linear
# 2024-09-29 13:59:09,458: hidden_size: 65
# 2024-09-29 13:59:09,458: initial_forget_bias: 3
# 2024-09-29 13:59:09,458: output_dropout: 0.5
# 2024-09-29 13:59:09,458: optimizer: Adam
# 2024-09-29 13:59:09,459: loss: MSE
# 2024-09-29 13:59:09,459: learning_rate: {0: 0.01, 30: 0.005, 40: 0.001}
# 2024-09-29 13:59:09,459: batch_size: 256
# 2024-09-29 13:59:09,459: epochs: 5
# 2024-09-29 13:59:09,460: clip_gradient_norm: 1
# 2024-09-29 13:59:09,460: predict_last_n: 1
# 2024-09-29 13:59:09,460: seq_length: 90
# 2024-09-29 13:59:09,460: num_workers: 1
# 2024-09-29 13:59:09,461: log_interval: 5
# 2024-09-29 13:59:09,461: log_tensorboard: True
# 2024-09-29 13:59:09,461: log_n_figures: 1
# 2024-09-29 13:59:09,462: save_weights_every: 1
# 2024-09-29 13:59:09,462: dataset: usace
# 2024-09-29 13:59:09,462: dynamic_inputs: ['MF_TuleR_S10ET-POTENTIAL', 'MF_TuleR_S10FLOW', 'MF_TuleR_S10PRECIP-INC', 'MF_TuleR_S10SATURATION FRACTION', 'MF_TuleR_S10STORAGE-SOIL', 'MF_TuleR_S10SWE-OBSERVED', 'MF_TuleR_S10TEMPERATURE-AIR', 'MF_TuleR_S20ET-POTENTIAL', 'MF_TuleR_S20FLOW', 'MF_TuleR_S20PRECIP-INC', 'MF_TuleR_S20SATURATION FRACTION', 'MF_TuleR_S20STORAGE-SOIL', 'MF_TuleR_S20SWE-OBSERVED', 'MF_TuleR_S20TEMPERATURE-AIR', 'NF_TuleR_S10ET-POTENTIAL', 'NF_TuleR_S10FLOW', 'NF_TuleR_S10PRECIP-INC', 'NF_TuleR_S10SATURATION FRACTION', 'NF_TuleR_S10STORAGE-SOIL', 'NF_TuleR_S10SWE-OBSERVED', 'NF_TuleR_S10TEMPERATURE-AIR', 'ReservoirInflowFLOW', 'SF_TuleR_S10ET-POTENTIAL', 'SF_TuleR_S10FLOW', 'SF_TuleR_S10PRECIP-INC', 'SF_TuleR_S10SATURATION FRACTION', 'SF_TuleR_S10STORAGE-SOIL', 'SF_TuleR_S10SWE-OBSERVED', 'SF_TuleR_S10TEMPERATURE-AIR', 'TuleR_S10ET-POTENTIAL', 'TuleR_S10FLOW', 'TuleR_S10PRECIP-INC', 'TuleR_S10SATURATION FRACTION', 'TuleR_S10STORAGE-SOIL', 'TuleR_S10TEMPERATURE-AIR', 'TuleR_S20ET-POTENTIAL', 'TuleR_S20FLOW', 'TuleR_S20PRECIP-INC', 'TuleR_S20SATURATION FRACTION', 'TuleR_S20STORAGE-SOIL', 'TuleR_S20SWE-OBSERVED', 'TuleR_S20TEMPERATURE-AIR']
# 2024-09-29 13:59:09,462: target_variables: ['ReservoirInflowFLOW-OBSERVED']
# 2024-09-29 13:59:09,463: number_of_basins: 1
# 2024-09-29 13:59:09,463: train_dir: /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test65_0.5_90_2909_135909/train_data
# 2024-09-29 13:59:09,463: img_log_dir: /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test65_0.5_90_2909_135909/img_log
# 2024-09-29 13:59:09,465: ### Device cpu will be used for training
# 2024-09-29 13:59:09,466: Loading basin data into xarray data set.
# 100%|██████████| 1/1 [00:00<00:00, 13.24it/s]
# 2024-09-29 13:59:09,562: Create lookup table and convert to pytorch tensor
# 100%|██████████| 1/1 [00:00<00:00, 16.67it/s]
# # Epoch 1: 100%|██████████| 23/23 [00:02<00:00, 10.93it/s, Loss: 0.1016]
# 2024-09-29 13:59:11,797: Epoch 1 average loss: avg_loss: 0.24138, avg_total_loss: 0.24138
# # Epoch 2: 100%|██████████| 23/23 [00:01<00:00, 11.65it/s, Loss: 0.0603]
# 2024-09-29 13:59:13,823: Epoch 2 average loss: avg_loss: 0.13156, avg_total_loss: 0.13156
# # Epoch 3: 100%|██████████| 23/23 [00:01<00:00, 11.77it/s, Loss: 0.0380]
# 2024-09-29 13:59:15,801: Epoch 3 average loss: avg_loss: 0.11395, avg_total_loss: 0.11395
# # Epoch 4: 100%|██████████| 23/23 [00:01<00:00, 11.75it/s, Loss: 0.0294]
# 2024-09-29 13:59:17,820: Epoch 4 average loss: avg_loss: 0.09770, avg_total_loss: 0.09770
# # Epoch 5: 100%|██████████| 23/23 [00:01<00:00, 11.77it/s, Loss: 0.0282]
# 2024-09-29 13:59:19,787: Epoch 5 average loss: avg_loss: 0.09065, avg_total_loss: 0.09065
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  4.40it/s]
# 2024-09-29 13:59:20,373: Epoch 5 average validation loss: 0.06452 -- Median validation metrics: avg_loss: 0.06452, NSE: 0.85288, MSE: 30512.24023
# 2024-09-29 13:59:20,395: Using the model weights from /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test65_0.5_90_2909_135909/model_epoch005.pt
# # Evaluation: 100%|██████████| 1/1 [00:00<00:00,  3.47it/s]
# 2024-09-29 13:59:20,692: Stored metrics at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test65_0.5_90_2909_135909/test/model_epoch005/test_metrics.csv
# 2024-09-29 13:59:20,695: Stored results at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test65_0.5_90_2909_135909/test/model_epoch005/test_results.p
# 2024-09-29 13:59:20,711: Using the model weights from /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test65_0.5_90_2909_135909/model_epoch005.pt
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  4.72it/s]
# 2024-09-29 13:59:20,934: Stored metrics at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test65_0.5_90_2909_135909/validation/model_epoch005/validation_metrics.csv
# 2024-09-29 13:59:20,939: Stored results at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test65_0.5_90_2909_135909/validation/model_epoch005/validation_results.p
# 2024-09-29 13:59:20,947: Logging to /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test66_0.5_90_2909_135920/output.log initialized.
# 2024-09-29 13:59:20,948: ### Folder structure created at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test66_0.5_90_2909_135920
# 2024-09-29 13:59:20,948: ### Run configurations for parallel_grid_search_test66_0.5_90
# 2024-09-29 13:59:20,949: data_dir: /global/scratch/users/evanrobert
# 2024-09-29 13:59:20,949: experiment_name: parallel_grid_search_test66_0.5_90
# 2024-09-29 13:59:20,949: run_dir: /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test66_0.5_90_2909_135920
# 2024-09-29 13:59:20,949: train_basin_file: ../initial_exploration/exploration_tuler
# 2024-09-29 13:59:20,950: validation_basin_file: ../initial_exploration/exploration_tuler
# 2024-09-29 13:59:20,950: test_basin_file: ../initial_exploration/exploration_tuler
# 2024-09-29 13:59:20,950: train_start_date: 1981-10-01 00:00:00
# 2024-09-29 13:59:20,951: train_end_date: 1997-09-30 00:00:00
# 2024-09-29 13:59:20,951: validation_start_date: 1997-10-01 00:00:00
# 2024-09-29 13:59:20,951: validation_end_date: 2000-09-30 00:00:00
# 2024-09-29 13:59:20,951: test_start_date: 2000-10-01 00:00:00
# 2024-09-29 13:59:20,952: test_end_date: 2005-09-30 00:00:00
# 2024-09-29 13:59:20,952: device: cpu
# 2024-09-29 13:59:20,952: validate_every: 5
# 2024-09-29 13:59:20,952: validate_n_random_basins: 1
# 2024-09-29 13:59:20,953: metrics: ['NSE', 'MSE']
# 2024-09-29 13:59:20,953: model: cudalstm
# 2024-09-29 13:59:20,953: head: regression
# 2024-09-29 13:59:20,954: output_activation: linear
# 2024-09-29 13:59:20,954: hidden_size: 66
# 2024-09-29 13:59:20,954: initial_forget_bias: 3
# 2024-09-29 13:59:20,954: output_dropout: 0.5
# 2024-09-29 13:59:20,955: optimizer: Adam
# 2024-09-29 13:59:20,955: loss: MSE
# 2024-09-29 13:59:20,955: learning_rate: {0: 0.01, 30: 0.005, 40: 0.001}
# 2024-09-29 13:59:20,955: batch_size: 256
# 2024-09-29 13:59:20,955: epochs: 5
# 2024-09-29 13:59:20,956: clip_gradient_norm: 1
# 2024-09-29 13:59:20,956: predict_last_n: 1
# 2024-09-29 13:59:20,956: seq_length: 90
# 2024-09-29 13:59:20,957: num_workers: 1
# 2024-09-29 13:59:20,957: log_interval: 5
# 2024-09-29 13:59:20,957: log_tensorboard: True
# 2024-09-29 13:59:20,958: log_n_figures: 1
# 2024-09-29 13:59:20,958: save_weights_every: 1
# 2024-09-29 13:59:20,958: dataset: usace
# 2024-09-29 13:59:20,958: dynamic_inputs: ['MF_TuleR_S10ET-POTENTIAL', 'MF_TuleR_S10FLOW', 'MF_TuleR_S10PRECIP-INC', 'MF_TuleR_S10SATURATION FRACTION', 'MF_TuleR_S10STORAGE-SOIL', 'MF_TuleR_S10SWE-OBSERVED', 'MF_TuleR_S10TEMPERATURE-AIR', 'MF_TuleR_S20ET-POTENTIAL', 'MF_TuleR_S20FLOW', 'MF_TuleR_S20PRECIP-INC', 'MF_TuleR_S20SATURATION FRACTION', 'MF_TuleR_S20STORAGE-SOIL', 'MF_TuleR_S20SWE-OBSERVED', 'MF_TuleR_S20TEMPERATURE-AIR', 'NF_TuleR_S10ET-POTENTIAL', 'NF_TuleR_S10FLOW', 'NF_TuleR_S10PRECIP-INC', 'NF_TuleR_S10SATURATION FRACTION', 'NF_TuleR_S10STORAGE-SOIL', 'NF_TuleR_S10SWE-OBSERVED', 'NF_TuleR_S10TEMPERATURE-AIR', 'ReservoirInflowFLOW', 'SF_TuleR_S10ET-POTENTIAL', 'SF_TuleR_S10FLOW', 'SF_TuleR_S10PRECIP-INC', 'SF_TuleR_S10SATURATION FRACTION', 'SF_TuleR_S10STORAGE-SOIL', 'SF_TuleR_S10SWE-OBSERVED', 'SF_TuleR_S10TEMPERATURE-AIR', 'TuleR_S10ET-POTENTIAL', 'TuleR_S10FLOW', 'TuleR_S10PRECIP-INC', 'TuleR_S10SATURATION FRACTION', 'TuleR_S10STORAGE-SOIL', 'TuleR_S10TEMPERATURE-AIR', 'TuleR_S20ET-POTENTIAL', 'TuleR_S20FLOW', 'TuleR_S20PRECIP-INC', 'TuleR_S20SATURATION FRACTION', 'TuleR_S20STORAGE-SOIL', 'TuleR_S20SWE-OBSERVED', 'TuleR_S20TEMPERATURE-AIR']
# 2024-09-29 13:59:20,959: target_variables: ['ReservoirInflowFLOW-OBSERVED']
# 2024-09-29 13:59:20,959: number_of_basins: 1
# 2024-09-29 13:59:20,959: train_dir: /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test66_0.5_90_2909_135920/train_data
# 2024-09-29 13:59:20,959: img_log_dir: /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test66_0.5_90_2909_135920/img_log
# 2024-09-29 13:59:20,961: ### Device cpu will be used for training
# 2024-09-29 13:59:20,962: Loading basin data into xarray data set.
# 100%|██████████| 1/1 [00:00<00:00, 13.06it/s]
# 2024-09-29 13:59:21,058: Create lookup table and convert to pytorch tensor
# 100%|██████████| 1/1 [00:00<00:00, 16.90it/s]
# # Epoch 1: 100%|██████████| 23/23 [00:02<00:00, 10.96it/s, Loss: 0.4331]
# 2024-09-29 13:59:23,285: Epoch 1 average loss: avg_loss: 0.26113, avg_total_loss: 0.26113
# # Epoch 2: 100%|██████████| 23/23 [00:02<00:00, 11.26it/s, Loss: 0.0340]
# 2024-09-29 13:59:25,374: Epoch 2 average loss: avg_loss: 0.13718, avg_total_loss: 0.13718
# # Epoch 3: 100%|██████████| 23/23 [00:02<00:00, 10.67it/s, Loss: 0.0288]
# 2024-09-29 13:59:27,566: Epoch 3 average loss: avg_loss: 0.10811, avg_total_loss: 0.10811
# # Epoch 4: 100%|██████████| 23/23 [00:01<00:00, 11.68it/s, Loss: 0.0906]
# 2024-09-29 13:59:29,600: Epoch 4 average loss: avg_loss: 0.09076, avg_total_loss: 0.09076
# # Epoch 5: 100%|██████████| 23/23 [00:01<00:00, 11.70it/s, Loss: 0.0725]
# 2024-09-29 13:59:31,670: Epoch 5 average loss: avg_loss: 0.09722, avg_total_loss: 0.09722
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  4.30it/s]
# 2024-09-29 13:59:32,219: Epoch 5 average validation loss: 0.04741 -- Median validation metrics: avg_loss: 0.04741, NSE: 0.89231, MSE: 22333.58594
# 2024-09-29 13:59:32,241: Using the model weights from /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test66_0.5_90_2909_135920/model_epoch005.pt
# # Evaluation: 100%|██████████| 1/1 [00:00<00:00,  3.52it/s]
# 2024-09-29 13:59:32,536: Stored metrics at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test66_0.5_90_2909_135920/test/model_epoch005/test_metrics.csv
# 2024-09-29 13:59:32,538: Stored results at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test66_0.5_90_2909_135920/test/model_epoch005/test_results.p
# 2024-09-29 13:59:32,554: Using the model weights from /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test66_0.5_90_2909_135920/model_epoch005.pt
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  4.74it/s]
# 2024-09-29 13:59:32,773: Stored metrics at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test66_0.5_90_2909_135920/validation/model_epoch005/validation_metrics.csv
# 2024-09-29 13:59:32,775: Stored results at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test66_0.5_90_2909_135920/validation/model_epoch005/validation_results.p
# 2024-09-29 13:59:32,786: Logging to /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test67_0.5_90_2909_135932/output.log initialized.
# 2024-09-29 13:59:32,786: ### Folder structure created at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test67_0.5_90_2909_135932
# 2024-09-29 13:59:32,787: ### Run configurations for parallel_grid_search_test67_0.5_90
# 2024-09-29 13:59:32,787: data_dir: /global/scratch/users/evanrobert
# 2024-09-29 13:59:32,787: experiment_name: parallel_grid_search_test67_0.5_90
# 2024-09-29 13:59:32,787: run_dir: /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test67_0.5_90_2909_135932
# 2024-09-29 13:59:32,788: train_basin_file: ../initial_exploration/exploration_tuler
# 2024-09-29 13:59:32,788: validation_basin_file: ../initial_exploration/exploration_tuler
# 2024-09-29 13:59:32,788: test_basin_file: ../initial_exploration/exploration_tuler
# 2024-09-29 13:59:32,789: train_start_date: 1981-10-01 00:00:00
# 2024-09-29 13:59:32,789: train_end_date: 1997-09-30 00:00:00
# 2024-09-29 13:59:32,790: validation_start_date: 1997-10-01 00:00:00
# 2024-09-29 13:59:32,790: validation_end_date: 2000-09-30 00:00:00
# 2024-09-29 13:59:32,790: test_start_date: 2000-10-01 00:00:00
# 2024-09-29 13:59:32,790: test_end_date: 2005-09-30 00:00:00
# 2024-09-29 13:59:32,791: device: cpu
# 2024-09-29 13:59:32,791: validate_every: 5
# 2024-09-29 13:59:32,791: validate_n_random_basins: 1
# 2024-09-29 13:59:32,792: metrics: ['NSE', 'MSE']
# 2024-09-29 13:59:32,792: model: cudalstm
# 2024-09-29 13:59:32,792: head: regression
# 2024-09-29 13:59:32,792: output_activation: linear
# 2024-09-29 13:59:32,793: hidden_size: 67
# 2024-09-29 13:59:32,793: initial_forget_bias: 3
# 2024-09-29 13:59:32,793: output_dropout: 0.5
# 2024-09-29 13:59:32,793: optimizer: Adam
# 2024-09-29 13:59:32,794: loss: MSE
# 2024-09-29 13:59:32,794: learning_rate: {0: 0.01, 30: 0.005, 40: 0.001}
# 2024-09-29 13:59:32,794: batch_size: 256
# 2024-09-29 13:59:32,795: epochs: 5
# 2024-09-29 13:59:32,795: clip_gradient_norm: 1
# 2024-09-29 13:59:32,795: predict_last_n: 1
# 2024-09-29 13:59:32,796: seq_length: 90
# 2024-09-29 13:59:32,796: num_workers: 1
# 2024-09-29 13:59:32,796: log_interval: 5
# 2024-09-29 13:59:32,796: log_tensorboard: True
# 2024-09-29 13:59:32,796: log_n_figures: 1
# 2024-09-29 13:59:32,797: save_weights_every: 1
# 2024-09-29 13:59:32,797: dataset: usace
# 2024-09-29 13:59:32,797: dynamic_inputs: ['MF_TuleR_S10ET-POTENTIAL', 'MF_TuleR_S10FLOW', 'MF_TuleR_S10PRECIP-INC', 'MF_TuleR_S10SATURATION FRACTION', 'MF_TuleR_S10STORAGE-SOIL', 'MF_TuleR_S10SWE-OBSERVED', 'MF_TuleR_S10TEMPERATURE-AIR', 'MF_TuleR_S20ET-POTENTIAL', 'MF_TuleR_S20FLOW', 'MF_TuleR_S20PRECIP-INC', 'MF_TuleR_S20SATURATION FRACTION', 'MF_TuleR_S20STORAGE-SOIL', 'MF_TuleR_S20SWE-OBSERVED', 'MF_TuleR_S20TEMPERATURE-AIR', 'NF_TuleR_S10ET-POTENTIAL', 'NF_TuleR_S10FLOW', 'NF_TuleR_S10PRECIP-INC', 'NF_TuleR_S10SATURATION FRACTION', 'NF_TuleR_S10STORAGE-SOIL', 'NF_TuleR_S10SWE-OBSERVED', 'NF_TuleR_S10TEMPERATURE-AIR', 'ReservoirInflowFLOW', 'SF_TuleR_S10ET-POTENTIAL', 'SF_TuleR_S10FLOW', 'SF_TuleR_S10PRECIP-INC', 'SF_TuleR_S10SATURATION FRACTION', 'SF_TuleR_S10STORAGE-SOIL', 'SF_TuleR_S10SWE-OBSERVED', 'SF_TuleR_S10TEMPERATURE-AIR', 'TuleR_S10ET-POTENTIAL', 'TuleR_S10FLOW', 'TuleR_S10PRECIP-INC', 'TuleR_S10SATURATION FRACTION', 'TuleR_S10STORAGE-SOIL', 'TuleR_S10TEMPERATURE-AIR', 'TuleR_S20ET-POTENTIAL', 'TuleR_S20FLOW', 'TuleR_S20PRECIP-INC', 'TuleR_S20SATURATION FRACTION', 'TuleR_S20STORAGE-SOIL', 'TuleR_S20SWE-OBSERVED', 'TuleR_S20TEMPERATURE-AIR']
# 2024-09-29 13:59:32,797: target_variables: ['ReservoirInflowFLOW-OBSERVED']
# 2024-09-29 13:59:32,798: number_of_basins: 1
# 2024-09-29 13:59:32,798: train_dir: /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test67_0.5_90_2909_135932/train_data
# 2024-09-29 13:59:32,798: img_log_dir: /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test67_0.5_90_2909_135932/img_log
# 2024-09-29 13:59:32,800: ### Device cpu will be used for training
# 2024-09-29 13:59:32,801: Loading basin data into xarray data set.
# 100%|██████████| 1/1 [00:00<00:00, 13.18it/s]
# 2024-09-29 13:59:32,898: Create lookup table and convert to pytorch tensor
# 100%|██████████| 1/1 [00:00<00:00, 17.37it/s]
# # Epoch 1: 100%|██████████| 23/23 [00:02<00:00, 11.43it/s, Loss: 0.1049]
# 2024-09-29 13:59:35,038: Epoch 1 average loss: avg_loss: 0.24114, avg_total_loss: 0.24114
# # Epoch 2: 100%|██████████| 23/23 [00:01<00:00, 11.50it/s, Loss: 0.0597]
# 2024-09-29 13:59:37,063: Epoch 2 average loss: avg_loss: 0.13311, avg_total_loss: 0.13311
# # Epoch 3: 100%|██████████| 23/23 [00:01<00:00, 11.54it/s, Loss: 0.0917]
# 2024-09-29 13:59:39,103: Epoch 3 average loss: avg_loss: 0.11259, avg_total_loss: 0.11259
# # Epoch 4: 100%|██████████| 23/23 [00:01<00:00, 11.58it/s, Loss: 0.0707]
# 2024-09-29 13:59:41,120: Epoch 4 average loss: avg_loss: 0.08694, avg_total_loss: 0.08694
# # Epoch 5: 100%|██████████| 23/23 [00:02<00:00, 11.50it/s, Loss: 0.0402]
# 2024-09-29 13:59:43,194: Epoch 5 average loss: avg_loss: 0.09078, avg_total_loss: 0.09078
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  4.44it/s]
# 2024-09-29 13:59:43,767: Epoch 5 average validation loss: 0.05383 -- Median validation metrics: avg_loss: 0.05383, NSE: 0.87720, MSE: 25468.55469
# 2024-09-29 13:59:43,790: Using the model weights from /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test67_0.5_90_2909_135932/model_epoch005.pt
# # Evaluation: 100%|██████████| 1/1 [00:00<00:00,  3.49it/s]
# 2024-09-29 13:59:44,085: Stored metrics at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test67_0.5_90_2909_135932/test/model_epoch005/test_metrics.csv
# 2024-09-29 13:59:44,087: Stored results at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test67_0.5_90_2909_135932/test/model_epoch005/test_results.p
# 2024-09-29 13:59:44,104: Using the model weights from /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test67_0.5_90_2909_135932/model_epoch005.pt
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  4.67it/s]
# 2024-09-29 13:59:44,325: Stored metrics at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test67_0.5_90_2909_135932/validation/model_epoch005/validation_metrics.csv
# 2024-09-29 13:59:44,328: Stored results at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test67_0.5_90_2909_135932/validation/model_epoch005/validation_results.p
# 2024-09-29 13:59:44,337: Logging to /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test68_0.5_90_2909_135944/output.log initialized.
# 2024-09-29 13:59:44,337: ### Folder structure created at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test68_0.5_90_2909_135944
# 2024-09-29 13:59:44,338: ### Run configurations for parallel_grid_search_test68_0.5_90
# 2024-09-29 13:59:44,338: data_dir: /global/scratch/users/evanrobert
# 2024-09-29 13:59:44,338: experiment_name: parallel_grid_search_test68_0.5_90
# 2024-09-29 13:59:44,338: run_dir: /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test68_0.5_90_2909_135944
# 2024-09-29 13:59:44,339: train_basin_file: ../initial_exploration/exploration_tuler
# 2024-09-29 13:59:44,339: validation_basin_file: ../initial_exploration/exploration_tuler
# 2024-09-29 13:59:44,339: test_basin_file: ../initial_exploration/exploration_tuler
# 2024-09-29 13:59:44,340: train_start_date: 1981-10-01 00:00:00
# 2024-09-29 13:59:44,340: train_end_date: 1997-09-30 00:00:00
# 2024-09-29 13:59:44,341: validation_start_date: 1997-10-01 00:00:00
# 2024-09-29 13:59:44,341: validation_end_date: 2000-09-30 00:00:00
# 2024-09-29 13:59:44,341: test_start_date: 2000-10-01 00:00:00
# 2024-09-29 13:59:44,341: test_end_date: 2005-09-30 00:00:00
# 2024-09-29 13:59:44,342: device: cpu
# 2024-09-29 13:59:44,342: validate_every: 5
# 2024-09-29 13:59:44,342: validate_n_random_basins: 1
# 2024-09-29 13:59:44,343: metrics: ['NSE', 'MSE']
# 2024-09-29 13:59:44,343: model: cudalstm
# 2024-09-29 13:59:44,343: head: regression
# 2024-09-29 13:59:44,343: output_activation: linear
# 2024-09-29 13:59:44,344: hidden_size: 68
# 2024-09-29 13:59:44,344: initial_forget_bias: 3
# 2024-09-29 13:59:44,344: output_dropout: 0.5
# 2024-09-29 13:59:44,345: optimizer: Adam
# 2024-09-29 13:59:44,345: loss: MSE
# 2024-09-29 13:59:44,345: learning_rate: {0: 0.01, 30: 0.005, 40: 0.001}
# 2024-09-29 13:59:44,345: batch_size: 256
# 2024-09-29 13:59:44,345: epochs: 5
# 2024-09-29 13:59:44,346: clip_gradient_norm: 1
# 2024-09-29 13:59:44,346: predict_last_n: 1
# 2024-09-29 13:59:44,346: seq_length: 90
# 2024-09-29 13:59:44,347: num_workers: 1
# 2024-09-29 13:59:44,347: log_interval: 5
# 2024-09-29 13:59:44,347: log_tensorboard: True
# 2024-09-29 13:59:44,347: log_n_figures: 1
# 2024-09-29 13:59:44,348: save_weights_every: 1
# 2024-09-29 13:59:44,348: dataset: usace
# 2024-09-29 13:59:44,348: dynamic_inputs: ['MF_TuleR_S10ET-POTENTIAL', 'MF_TuleR_S10FLOW', 'MF_TuleR_S10PRECIP-INC', 'MF_TuleR_S10SATURATION FRACTION', 'MF_TuleR_S10STORAGE-SOIL', 'MF_TuleR_S10SWE-OBSERVED', 'MF_TuleR_S10TEMPERATURE-AIR', 'MF_TuleR_S20ET-POTENTIAL', 'MF_TuleR_S20FLOW', 'MF_TuleR_S20PRECIP-INC', 'MF_TuleR_S20SATURATION FRACTION', 'MF_TuleR_S20STORAGE-SOIL', 'MF_TuleR_S20SWE-OBSERVED', 'MF_TuleR_S20TEMPERATURE-AIR', 'NF_TuleR_S10ET-POTENTIAL', 'NF_TuleR_S10FLOW', 'NF_TuleR_S10PRECIP-INC', 'NF_TuleR_S10SATURATION FRACTION', 'NF_TuleR_S10STORAGE-SOIL', 'NF_TuleR_S10SWE-OBSERVED', 'NF_TuleR_S10TEMPERATURE-AIR', 'ReservoirInflowFLOW', 'SF_TuleR_S10ET-POTENTIAL', 'SF_TuleR_S10FLOW', 'SF_TuleR_S10PRECIP-INC', 'SF_TuleR_S10SATURATION FRACTION', 'SF_TuleR_S10STORAGE-SOIL', 'SF_TuleR_S10SWE-OBSERVED', 'SF_TuleR_S10TEMPERATURE-AIR', 'TuleR_S10ET-POTENTIAL', 'TuleR_S10FLOW', 'TuleR_S10PRECIP-INC', 'TuleR_S10SATURATION FRACTION', 'TuleR_S10STORAGE-SOIL', 'TuleR_S10TEMPERATURE-AIR', 'TuleR_S20ET-POTENTIAL', 'TuleR_S20FLOW', 'TuleR_S20PRECIP-INC', 'TuleR_S20SATURATION FRACTION', 'TuleR_S20STORAGE-SOIL', 'TuleR_S20SWE-OBSERVED', 'TuleR_S20TEMPERATURE-AIR']
# 2024-09-29 13:59:44,348: target_variables: ['ReservoirInflowFLOW-OBSERVED']
# 2024-09-29 13:59:44,349: number_of_basins: 1
# 2024-09-29 13:59:44,349: train_dir: /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test68_0.5_90_2909_135944/train_data
# 2024-09-29 13:59:44,349: img_log_dir: /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test68_0.5_90_2909_135944/img_log
# 2024-09-29 13:59:44,351: ### Device cpu will be used for training
# 2024-09-29 13:59:44,352: Loading basin data into xarray data set.
# 100%|██████████| 1/1 [00:00<00:00, 13.04it/s]
# 2024-09-29 13:59:44,450: Create lookup table and convert to pytorch tensor
# 100%|██████████| 1/1 [00:00<00:00, 17.03it/s]
# # Epoch 1: 100%|██████████| 23/23 [00:02<00:00, 11.41it/s, Loss: 0.0755]
# 2024-09-29 13:59:46,796: Epoch 1 average loss: avg_loss: 0.22838, avg_total_loss: 0.22838
# # Epoch 2: 100%|██████████| 23/23 [00:02<00:00, 11.50it/s, Loss: 0.0283]
# 2024-09-29 13:59:48,858: Epoch 2 average loss: avg_loss: 0.12610, avg_total_loss: 0.12610
# # Epoch 3: 100%|██████████| 23/23 [00:01<00:00, 11.67it/s, Loss: 0.0858]
# 2024-09-29 13:59:51,060: Epoch 3 average loss: avg_loss: 0.10543, avg_total_loss: 0.10543
# # Epoch 4: 100%|██████████| 23/23 [00:01<00:00, 11.55it/s, Loss: 0.0442]
# 2024-09-29 13:59:53,097: Epoch 4 average loss: avg_loss: 0.10294, avg_total_loss: 0.10294
# # Epoch 5: 100%|██████████| 23/23 [00:02<00:00, 11.35it/s, Loss: 0.0617]
# 2024-09-29 13:59:55,197: Epoch 5 average loss: avg_loss: 0.08774, avg_total_loss: 0.08774
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  4.53it/s]
# 2024-09-29 13:59:55,726: Epoch 5 average validation loss: 0.05068 -- Median validation metrics: avg_loss: 0.05068, NSE: 0.88493, MSE: 23864.92578
# 2024-09-29 13:59:55,747: Using the model weights from /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test68_0.5_90_2909_135944/model_epoch005.pt
# # Evaluation: 100%|██████████| 1/1 [00:00<00:00,  3.51it/s]
# 2024-09-29 13:59:56,041: Stored metrics at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test68_0.5_90_2909_135944/test/model_epoch005/test_metrics.csv
# 2024-09-29 13:59:56,044: Stored results at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test68_0.5_90_2909_135944/test/model_epoch005/test_results.p
# 2024-09-29 13:59:56,061: Using the model weights from /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test68_0.5_90_2909_135944/model_epoch005.pt
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  4.85it/s]
# 2024-09-29 13:59:56,274: Stored metrics at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test68_0.5_90_2909_135944/validation/model_epoch005/validation_metrics.csv
# 2024-09-29 13:59:56,277: Stored results at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test68_0.5_90_2909_135944/validation/model_epoch005/validation_results.p
# 2024-09-29 13:59:56,285: Logging to /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test69_0.5_90_2909_135956/output.log initialized.
# 2024-09-29 13:59:56,285: ### Folder structure created at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test69_0.5_90_2909_135956
# 2024-09-29 13:59:56,286: ### Run configurations for parallel_grid_search_test69_0.5_90
# 2024-09-29 13:59:56,286: data_dir: /global/scratch/users/evanrobert
# 2024-09-29 13:59:56,286: experiment_name: parallel_grid_search_test69_0.5_90
# 2024-09-29 13:59:56,287: run_dir: /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test69_0.5_90_2909_135956
# 2024-09-29 13:59:56,287: train_basin_file: ../initial_exploration/exploration_tuler
# 2024-09-29 13:59:56,287: validation_basin_file: ../initial_exploration/exploration_tuler
# 2024-09-29 13:59:56,287: test_basin_file: ../initial_exploration/exploration_tuler
# 2024-09-29 13:59:56,288: train_start_date: 1981-10-01 00:00:00
# 2024-09-29 13:59:56,288: train_end_date: 1997-09-30 00:00:00
# 2024-09-29 13:59:56,288: validation_start_date: 1997-10-01 00:00:00
# 2024-09-29 13:59:56,289: validation_end_date: 2000-09-30 00:00:00
# 2024-09-29 13:59:56,289: test_start_date: 2000-10-01 00:00:00
# 2024-09-29 13:59:56,289: test_end_date: 2005-09-30 00:00:00
# 2024-09-29 13:59:56,290: device: cpu
# 2024-09-29 13:59:56,290: validate_every: 5
# 2024-09-29 13:59:56,290: validate_n_random_basins: 1
# 2024-09-29 13:59:56,291: metrics: ['NSE', 'MSE']
# 2024-09-29 13:59:56,291: model: cudalstm
# 2024-09-29 13:59:56,291: head: regression
# 2024-09-29 13:59:56,291: output_activation: linear
# 2024-09-29 13:59:56,292: hidden_size: 69
# 2024-09-29 13:59:56,292: initial_forget_bias: 3
# 2024-09-29 13:59:56,293: output_dropout: 0.5
# 2024-09-29 13:59:56,293: optimizer: Adam
# 2024-09-29 13:59:56,293: loss: MSE
# 2024-09-29 13:59:56,294: learning_rate: {0: 0.01, 30: 0.005, 40: 0.001}
# 2024-09-29 13:59:56,294: batch_size: 256
# 2024-09-29 13:59:56,294: epochs: 5
# 2024-09-29 13:59:56,295: clip_gradient_norm: 1
# 2024-09-29 13:59:56,295: predict_last_n: 1
# 2024-09-29 13:59:56,295: seq_length: 90
# 2024-09-29 13:59:56,295: num_workers: 1
# 2024-09-29 13:59:56,296: log_interval: 5
# 2024-09-29 13:59:56,296: log_tensorboard: True
# 2024-09-29 13:59:56,296: log_n_figures: 1
# 2024-09-29 13:59:56,296: save_weights_every: 1
# 2024-09-29 13:59:56,297: dataset: usace
# 2024-09-29 13:59:56,297: dynamic_inputs: ['MF_TuleR_S10ET-POTENTIAL', 'MF_TuleR_S10FLOW', 'MF_TuleR_S10PRECIP-INC', 'MF_TuleR_S10SATURATION FRACTION', 'MF_TuleR_S10STORAGE-SOIL', 'MF_TuleR_S10SWE-OBSERVED', 'MF_TuleR_S10TEMPERATURE-AIR', 'MF_TuleR_S20ET-POTENTIAL', 'MF_TuleR_S20FLOW', 'MF_TuleR_S20PRECIP-INC', 'MF_TuleR_S20SATURATION FRACTION', 'MF_TuleR_S20STORAGE-SOIL', 'MF_TuleR_S20SWE-OBSERVED', 'MF_TuleR_S20TEMPERATURE-AIR', 'NF_TuleR_S10ET-POTENTIAL', 'NF_TuleR_S10FLOW', 'NF_TuleR_S10PRECIP-INC', 'NF_TuleR_S10SATURATION FRACTION', 'NF_TuleR_S10STORAGE-SOIL', 'NF_TuleR_S10SWE-OBSERVED', 'NF_TuleR_S10TEMPERATURE-AIR', 'ReservoirInflowFLOW', 'SF_TuleR_S10ET-POTENTIAL', 'SF_TuleR_S10FLOW', 'SF_TuleR_S10PRECIP-INC', 'SF_TuleR_S10SATURATION FRACTION', 'SF_TuleR_S10STORAGE-SOIL', 'SF_TuleR_S10SWE-OBSERVED', 'SF_TuleR_S10TEMPERATURE-AIR', 'TuleR_S10ET-POTENTIAL', 'TuleR_S10FLOW', 'TuleR_S10PRECIP-INC', 'TuleR_S10SATURATION FRACTION', 'TuleR_S10STORAGE-SOIL', 'TuleR_S10TEMPERATURE-AIR', 'TuleR_S20ET-POTENTIAL', 'TuleR_S20FLOW', 'TuleR_S20PRECIP-INC', 'TuleR_S20SATURATION FRACTION', 'TuleR_S20STORAGE-SOIL', 'TuleR_S20SWE-OBSERVED', 'TuleR_S20TEMPERATURE-AIR']
# 2024-09-29 13:59:56,297: target_variables: ['ReservoirInflowFLOW-OBSERVED']
# 2024-09-29 13:59:56,297: number_of_basins: 1
# 2024-09-29 13:59:56,298: train_dir: /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test69_0.5_90_2909_135956/train_data
# 2024-09-29 13:59:56,298: img_log_dir: /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test69_0.5_90_2909_135956/img_log
# 2024-09-29 13:59:56,300: ### Device cpu will be used for training
# 2024-09-29 13:59:56,300: Loading basin data into xarray data set.
# 100%|██████████| 1/1 [00:00<00:00, 13.32it/s]
# 2024-09-29 13:59:56,396: Create lookup table and convert to pytorch tensor
# 100%|██████████| 1/1 [00:00<00:00, 17.25it/s]
# # Epoch 1: 100%|██████████| 23/23 [00:02<00:00, 11.12it/s, Loss: 0.0572]
# 2024-09-29 13:59:58,594: Epoch 1 average loss: avg_loss: 0.25313, avg_total_loss: 0.25313
# # Epoch 2: 100%|██████████| 23/23 [00:02<00:00, 11.04it/s, Loss: 0.0293]
# 2024-09-29 14:00:00,753: Epoch 2 average loss: avg_loss: 0.14238, avg_total_loss: 0.14238
# # Epoch 3: 100%|██████████| 23/23 [00:02<00:00, 10.95it/s, Loss: 0.0185]
# 2024-09-29 14:00:02,907: Epoch 3 average loss: avg_loss: 0.11371, avg_total_loss: 0.11371
# # Epoch 4: 100%|██████████| 23/23 [00:02<00:00, 11.18it/s, Loss: 0.0360]
# 2024-09-29 14:00:05,046: Epoch 4 average loss: avg_loss: 0.10258, avg_total_loss: 0.10258
# # Epoch 5: 100%|██████████| 23/23 [00:02<00:00, 11.24it/s, Loss: 0.0304]
# 2024-09-29 14:00:07,123: Epoch 5 average loss: avg_loss: 0.08063, avg_total_loss: 0.08063
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  4.15it/s]
# 2024-09-29 14:00:07,731: Epoch 5 average validation loss: 0.06175 -- Median validation metrics: avg_loss: 0.06175, NSE: 0.85933, MSE: 29174.90234
# 2024-09-29 14:00:07,753: Using the model weights from /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test69_0.5_90_2909_135956/model_epoch005.pt
# # Evaluation: 100%|██████████| 1/1 [00:00<00:00,  3.44it/s]
# 2024-09-29 14:00:08,056: Stored metrics at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test69_0.5_90_2909_135956/test/model_epoch005/test_metrics.csv
# 2024-09-29 14:00:08,059: Stored results at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test69_0.5_90_2909_135956/test/model_epoch005/test_results.p
# 2024-09-29 14:00:08,076: Using the model weights from /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test69_0.5_90_2909_135956/model_epoch005.pt
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  4.78it/s]
# 2024-09-29 14:00:08,292: Stored metrics at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test69_0.5_90_2909_135956/validation/model_epoch005/validation_metrics.csv
# 2024-09-29 14:00:08,296: Stored results at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test69_0.5_90_2909_135956/validation/model_epoch005/validation_results.p
# 2024-09-29 14:00:08,304: Logging to /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test70_0.5_90_2909_140008/output.log initialized.
# 2024-09-29 14:00:08,305: ### Folder structure created at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test70_0.5_90_2909_140008
# 2024-09-29 14:00:08,306: ### Run configurations for parallel_grid_search_test70_0.5_90
# 2024-09-29 14:00:08,306: data_dir: /global/scratch/users/evanrobert
# 2024-09-29 14:00:08,306: experiment_name: parallel_grid_search_test70_0.5_90
# 2024-09-29 14:00:08,306: run_dir: /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test70_0.5_90_2909_140008
# 2024-09-29 14:00:08,307: train_basin_file: ../initial_exploration/exploration_tuler
# 2024-09-29 14:00:08,307: validation_basin_file: ../initial_exploration/exploration_tuler
# 2024-09-29 14:00:08,307: test_basin_file: ../initial_exploration/exploration_tuler
# 2024-09-29 14:00:08,307: train_start_date: 1981-10-01 00:00:00
# 2024-09-29 14:00:08,308: train_end_date: 1997-09-30 00:00:00
# 2024-09-29 14:00:08,308: validation_start_date: 1997-10-01 00:00:00
# 2024-09-29 14:00:08,308: validation_end_date: 2000-09-30 00:00:00
# 2024-09-29 14:00:08,308: test_start_date: 2000-10-01 00:00:00
# 2024-09-29 14:00:08,309: test_end_date: 2005-09-30 00:00:00
# 2024-09-29 14:00:08,309: device: cpu
# 2024-09-29 14:00:08,310: validate_every: 5
# 2024-09-29 14:00:08,310: validate_n_random_basins: 1
# 2024-09-29 14:00:08,310: metrics: ['NSE', 'MSE']
# 2024-09-29 14:00:08,310: model: cudalstm
# 2024-09-29 14:00:08,311: head: regression
# 2024-09-29 14:00:08,311: output_activation: linear
# 2024-09-29 14:00:08,311: hidden_size: 70
# 2024-09-29 14:00:08,311: initial_forget_bias: 3
# 2024-09-29 14:00:08,312: output_dropout: 0.5
# 2024-09-29 14:00:08,312: optimizer: Adam
# 2024-09-29 14:00:08,312: loss: MSE
# 2024-09-29 14:00:08,313: learning_rate: {0: 0.01, 30: 0.005, 40: 0.001}
# 2024-09-29 14:00:08,313: batch_size: 256
# 2024-09-29 14:00:08,313: epochs: 5
# 2024-09-29 14:00:08,313: clip_gradient_norm: 1
# 2024-09-29 14:00:08,313: predict_last_n: 1
# 2024-09-29 14:00:08,314: seq_length: 90
# 2024-09-29 14:00:08,314: num_workers: 1
# 2024-09-29 14:00:08,314: log_interval: 5
# 2024-09-29 14:00:08,315: log_tensorboard: True
# 2024-09-29 14:00:08,315: log_n_figures: 1
# 2024-09-29 14:00:08,315: save_weights_every: 1
# 2024-09-29 14:00:08,315: dataset: usace
# ...
# 2024-09-29 14:05:19,455: target_variables: ['ReservoirInflowFLOW-OBSERVED']
# 2024-09-29 14:05:19,455: number_of_basins: 1
# 2024-09-29 14:05:19,456: train_dir: /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test92_0.5_90_2909_140519/train_data
# 2024-09-29 14:05:19,456: img_log_dir: /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test92_0.5_90_2909_140519/img_log
# 2024-09-29 14:05:19,458: ### Device cpu will be used for training
# 2024-09-29 14:05:19,459: Loading basin data into xarray data set.
# 100%|██████████| 1/1 [00:00<00:00, 12.72it/s]
# 2024-09-29 14:05:19,558: Create lookup table and convert to pytorch tensor
# 100%|██████████| 1/1 [00:00<00:00, 16.54it/s]
# # Epoch 1: 100%|██████████| 23/23 [00:02<00:00,  7.75it/s, Loss: 0.0424]
# 2024-09-29 14:05:22,657: Epoch 1 average loss: avg_loss: 0.22192, avg_total_loss: 0.22192
# # Epoch 2: 100%|██████████| 23/23 [00:02<00:00,  7.80it/s, Loss: 0.0478]
# 2024-09-29 14:05:25,638: Epoch 2 average loss: avg_loss: 0.11915, avg_total_loss: 0.11915
# # Epoch 3: 100%|██████████| 23/23 [00:02<00:00,  8.16it/s, Loss: 0.2321]
# 2024-09-29 14:05:28,566: Epoch 3 average loss: avg_loss: 0.09610, avg_total_loss: 0.09610
# # Epoch 4: 100%|██████████| 23/23 [00:02<00:00,  8.25it/s, Loss: 0.0773]
# 2024-09-29 14:05:31,473: Epoch 4 average loss: avg_loss: 0.09180, avg_total_loss: 0.09180
# # Epoch 5: 100%|██████████| 23/23 [00:02<00:00,  7.91it/s, Loss: 0.0487]
# 2024-09-29 14:05:34,450: Epoch 5 average loss: avg_loss: 0.07943, avg_total_loss: 0.07943
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  3.74it/s]
# 2024-09-29 14:05:35,085: Epoch 5 average validation loss: 0.04985 -- Median validation metrics: avg_loss: 0.04985, NSE: 0.88746, MSE: 23341.00781
# 2024-09-29 14:05:35,109: Using the model weights from /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test92_0.5_90_2909_140519/model_epoch005.pt
# # Evaluation: 100%|██████████| 1/1 [00:00<00:00,  2.84it/s]
# 2024-09-29 14:05:35,469: Stored metrics at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test92_0.5_90_2909_140519/test/model_epoch005/test_metrics.csv
# 2024-09-29 14:05:35,472: Stored results at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test92_0.5_90_2909_140519/test/model_epoch005/test_results.p
# 2024-09-29 14:05:35,489: Using the model weights from /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test92_0.5_90_2909_140519/model_epoch005.pt
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  3.95it/s]
# 2024-09-29 14:05:35,752: Stored metrics at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test92_0.5_90_2909_140519/validation/model_epoch005/validation_metrics.csv
# 2024-09-29 14:05:35,758: Stored results at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test92_0.5_90_2909_140519/validation/model_epoch005/validation_results.p
# 2024-09-29 14:05:35,768: Logging to /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test93_0.5_90_2909_140535/output.log initialized.
# 2024-09-29 14:05:35,768: ### Folder structure created at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test93_0.5_90_2909_140535
# 2024-09-29 14:05:35,768: ### Run configurations for parallel_grid_search_test93_0.5_90
# 2024-09-29 14:05:35,769: data_dir: /global/scratch/users/evanrobert
# 2024-09-29 14:05:35,769: experiment_name: parallel_grid_search_test93_0.5_90
# 2024-09-29 14:05:35,769: run_dir: /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test93_0.5_90_2909_140535
# 2024-09-29 14:05:35,770: train_basin_file: ../initial_exploration/exploration_tuler
# 2024-09-29 14:05:35,770: validation_basin_file: ../initial_exploration/exploration_tuler
# 2024-09-29 14:05:35,770: test_basin_file: ../initial_exploration/exploration_tuler
# 2024-09-29 14:05:35,770: train_start_date: 1981-10-01 00:00:00
# 2024-09-29 14:05:35,771: train_end_date: 1997-09-30 00:00:00
# 2024-09-29 14:05:35,771: validation_start_date: 1997-10-01 00:00:00
# 2024-09-29 14:05:35,771: validation_end_date: 2000-09-30 00:00:00
# 2024-09-29 14:05:35,771: test_start_date: 2000-10-01 00:00:00
# 2024-09-29 14:05:35,772: test_end_date: 2005-09-30 00:00:00
# 2024-09-29 14:05:35,772: device: cpu
# 2024-09-29 14:05:35,772: validate_every: 5
# 2024-09-29 14:05:35,773: validate_n_random_basins: 1
# 2024-09-29 14:05:35,773: metrics: ['NSE', 'MSE']
# 2024-09-29 14:05:35,773: model: cudalstm
# 2024-09-29 14:05:35,773: head: regression
# 2024-09-29 14:05:35,774: output_activation: linear
# 2024-09-29 14:05:35,774: hidden_size: 93
# 2024-09-29 14:05:35,774: initial_forget_bias: 3
# 2024-09-29 14:05:35,774: output_dropout: 0.5
# 2024-09-29 14:05:35,775: optimizer: Adam
# 2024-09-29 14:05:35,775: loss: MSE
# 2024-09-29 14:05:35,775: learning_rate: {0: 0.01, 30: 0.005, 40: 0.001}
# 2024-09-29 14:05:35,775: batch_size: 256
# 2024-09-29 14:05:35,776: epochs: 5
# 2024-09-29 14:05:35,776: clip_gradient_norm: 1
# 2024-09-29 14:05:35,776: predict_last_n: 1
# 2024-09-29 14:05:35,777: seq_length: 90
# 2024-09-29 14:05:35,777: num_workers: 1
# 2024-09-29 14:05:35,777: log_interval: 5
# 2024-09-29 14:05:35,777: log_tensorboard: True
# 2024-09-29 14:05:35,778: log_n_figures: 1
# 2024-09-29 14:05:35,778: save_weights_every: 1
# 2024-09-29 14:05:35,778: dataset: usace
# 2024-09-29 14:05:35,778: dynamic_inputs: ['MF_TuleR_S10ET-POTENTIAL', 'MF_TuleR_S10FLOW', 'MF_TuleR_S10PRECIP-INC', 'MF_TuleR_S10SATURATION FRACTION', 'MF_TuleR_S10STORAGE-SOIL', 'MF_TuleR_S10SWE-OBSERVED', 'MF_TuleR_S10TEMPERATURE-AIR', 'MF_TuleR_S20ET-POTENTIAL', 'MF_TuleR_S20FLOW', 'MF_TuleR_S20PRECIP-INC', 'MF_TuleR_S20SATURATION FRACTION', 'MF_TuleR_S20STORAGE-SOIL', 'MF_TuleR_S20SWE-OBSERVED', 'MF_TuleR_S20TEMPERATURE-AIR', 'NF_TuleR_S10ET-POTENTIAL', 'NF_TuleR_S10FLOW', 'NF_TuleR_S10PRECIP-INC', 'NF_TuleR_S10SATURATION FRACTION', 'NF_TuleR_S10STORAGE-SOIL', 'NF_TuleR_S10SWE-OBSERVED', 'NF_TuleR_S10TEMPERATURE-AIR', 'ReservoirInflowFLOW', 'SF_TuleR_S10ET-POTENTIAL', 'SF_TuleR_S10FLOW', 'SF_TuleR_S10PRECIP-INC', 'SF_TuleR_S10SATURATION FRACTION', 'SF_TuleR_S10STORAGE-SOIL', 'SF_TuleR_S10SWE-OBSERVED', 'SF_TuleR_S10TEMPERATURE-AIR', 'TuleR_S10ET-POTENTIAL', 'TuleR_S10FLOW', 'TuleR_S10PRECIP-INC', 'TuleR_S10SATURATION FRACTION', 'TuleR_S10STORAGE-SOIL', 'TuleR_S10TEMPERATURE-AIR', 'TuleR_S20ET-POTENTIAL', 'TuleR_S20FLOW', 'TuleR_S20PRECIP-INC', 'TuleR_S20SATURATION FRACTION', 'TuleR_S20STORAGE-SOIL', 'TuleR_S20SWE-OBSERVED', 'TuleR_S20TEMPERATURE-AIR']
# 2024-09-29 14:05:35,779: target_variables: ['ReservoirInflowFLOW-OBSERVED']
# 2024-09-29 14:05:35,779: number_of_basins: 1
# 2024-09-29 14:05:35,779: train_dir: /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test93_0.5_90_2909_140535/train_data
# 2024-09-29 14:05:35,779: img_log_dir: /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test93_0.5_90_2909_140535/img_log
# 2024-09-29 14:05:35,781: ### Device cpu will be used for training
# 2024-09-29 14:05:35,782: Loading basin data into xarray data set.
# 100%|██████████| 1/1 [00:00<00:00, 11.95it/s]
# 2024-09-29 14:05:35,888: Create lookup table and convert to pytorch tensor
# 100%|██████████| 1/1 [00:00<00:00, 16.70it/s]
# # Epoch 1: 100%|██████████| 23/23 [00:02<00:00,  7.83it/s, Loss: 0.0322]
# 2024-09-29 14:05:38,961: Epoch 1 average loss: avg_loss: 0.23694, avg_total_loss: 0.23694
# # Epoch 2: 100%|██████████| 23/23 [00:02<00:00,  7.94it/s, Loss: 0.0445]
# 2024-09-29 14:05:41,961: Epoch 2 average loss: avg_loss: 0.11851, avg_total_loss: 0.11851
# # Epoch 3: 100%|██████████| 23/23 [00:02<00:00,  8.08it/s, Loss: 0.0236]
# 2024-09-29 14:05:44,857: Epoch 3 average loss: avg_loss: 0.09157, avg_total_loss: 0.09157
# # Epoch 4: 100%|██████████| 23/23 [00:02<00:00,  8.00it/s, Loss: 0.0371]
# 2024-09-29 14:05:47,752: Epoch 4 average loss: avg_loss: 0.08211, avg_total_loss: 0.08211
# # Epoch 5: 100%|██████████| 23/23 [00:02<00:00,  8.07it/s, Loss: 0.1025]
# 2024-09-29 14:05:50,675: Epoch 5 average loss: avg_loss: 0.08445, avg_total_loss: 0.08445
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  3.78it/s]
# 2024-09-29 14:05:51,316: Epoch 5 average validation loss: 0.04983 -- Median validation metrics: avg_loss: 0.04983, NSE: 0.88647, MSE: 23544.71094
# 2024-09-29 14:05:51,340: Using the model weights from /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test93_0.5_90_2909_140535/model_epoch005.pt
# # Evaluation: 100%|██████████| 1/1 [00:00<00:00,  2.93it/s]
# 2024-09-29 14:05:51,690: Stored metrics at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test93_0.5_90_2909_140535/test/model_epoch005/test_metrics.csv
# 2024-09-29 14:05:51,692: Stored results at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test93_0.5_90_2909_140535/test/model_epoch005/test_results.p
# 2024-09-29 14:05:51,709: Using the model weights from /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test93_0.5_90_2909_140535/model_epoch005.pt
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  4.07it/s]
# 2024-09-29 14:05:51,963: Stored metrics at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test93_0.5_90_2909_140535/validation/model_epoch005/validation_metrics.csv
# 2024-09-29 14:05:51,966: Stored results at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test93_0.5_90_2909_140535/validation/model_epoch005/validation_results.p
# 2024-09-29 14:05:51,973: Logging to /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test94_0.5_90_2909_140551/output.log initialized.
# 2024-09-29 14:05:51,974: ### Folder structure created at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test94_0.5_90_2909_140551
# 2024-09-29 14:05:51,974: ### Run configurations for parallel_grid_search_test94_0.5_90
# 2024-09-29 14:05:51,975: data_dir: /global/scratch/users/evanrobert
# 2024-09-29 14:05:51,975: experiment_name: parallel_grid_search_test94_0.5_90
# 2024-09-29 14:05:51,975: run_dir: /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test94_0.5_90_2909_140551
# 2024-09-29 14:05:51,975: train_basin_file: ../initial_exploration/exploration_tuler
# 2024-09-29 14:05:51,976: validation_basin_file: ../initial_exploration/exploration_tuler
# 2024-09-29 14:05:51,976: test_basin_file: ../initial_exploration/exploration_tuler
# 2024-09-29 14:05:51,976: train_start_date: 1981-10-01 00:00:00
# 2024-09-29 14:05:51,977: train_end_date: 1997-09-30 00:00:00
# 2024-09-29 14:05:51,977: validation_start_date: 1997-10-01 00:00:00
# 2024-09-29 14:05:51,977: validation_end_date: 2000-09-30 00:00:00
# 2024-09-29 14:05:51,977: test_start_date: 2000-10-01 00:00:00
# 2024-09-29 14:05:51,978: test_end_date: 2005-09-30 00:00:00
# 2024-09-29 14:05:51,978: device: cpu
# 2024-09-29 14:05:51,978: validate_every: 5
# 2024-09-29 14:05:51,979: validate_n_random_basins: 1
# 2024-09-29 14:05:51,979: metrics: ['NSE', 'MSE']
# 2024-09-29 14:05:51,979: model: cudalstm
# 2024-09-29 14:05:51,979: head: regression
# 2024-09-29 14:05:51,980: output_activation: linear
# 2024-09-29 14:05:51,980: hidden_size: 94
# 2024-09-29 14:05:51,980: initial_forget_bias: 3
# 2024-09-29 14:05:51,980: output_dropout: 0.5
# 2024-09-29 14:05:51,981: optimizer: Adam
# 2024-09-29 14:05:51,981: loss: MSE
# 2024-09-29 14:05:51,982: learning_rate: {0: 0.01, 30: 0.005, 40: 0.001}
# 2024-09-29 14:05:51,982: batch_size: 256
# 2024-09-29 14:05:51,982: epochs: 5
# 2024-09-29 14:05:51,983: clip_gradient_norm: 1
# 2024-09-29 14:05:51,983: predict_last_n: 1
# 2024-09-29 14:05:51,983: seq_length: 90
# 2024-09-29 14:05:51,983: num_workers: 1
# 2024-09-29 14:05:51,983: log_interval: 5
# 2024-09-29 14:05:51,984: log_tensorboard: True
# 2024-09-29 14:05:51,984: log_n_figures: 1
# 2024-09-29 14:05:51,984: save_weights_every: 1
# 2024-09-29 14:05:51,985: dataset: usace
# 2024-09-29 14:05:51,985: dynamic_inputs: ['MF_TuleR_S10ET-POTENTIAL', 'MF_TuleR_S10FLOW', 'MF_TuleR_S10PRECIP-INC', 'MF_TuleR_S10SATURATION FRACTION', 'MF_TuleR_S10STORAGE-SOIL', 'MF_TuleR_S10SWE-OBSERVED', 'MF_TuleR_S10TEMPERATURE-AIR', 'MF_TuleR_S20ET-POTENTIAL', 'MF_TuleR_S20FLOW', 'MF_TuleR_S20PRECIP-INC', 'MF_TuleR_S20SATURATION FRACTION', 'MF_TuleR_S20STORAGE-SOIL', 'MF_TuleR_S20SWE-OBSERVED', 'MF_TuleR_S20TEMPERATURE-AIR', 'NF_TuleR_S10ET-POTENTIAL', 'NF_TuleR_S10FLOW', 'NF_TuleR_S10PRECIP-INC', 'NF_TuleR_S10SATURATION FRACTION', 'NF_TuleR_S10STORAGE-SOIL', 'NF_TuleR_S10SWE-OBSERVED', 'NF_TuleR_S10TEMPERATURE-AIR', 'ReservoirInflowFLOW', 'SF_TuleR_S10ET-POTENTIAL', 'SF_TuleR_S10FLOW', 'SF_TuleR_S10PRECIP-INC', 'SF_TuleR_S10SATURATION FRACTION', 'SF_TuleR_S10STORAGE-SOIL', 'SF_TuleR_S10SWE-OBSERVED', 'SF_TuleR_S10TEMPERATURE-AIR', 'TuleR_S10ET-POTENTIAL', 'TuleR_S10FLOW', 'TuleR_S10PRECIP-INC', 'TuleR_S10SATURATION FRACTION', 'TuleR_S10STORAGE-SOIL', 'TuleR_S10TEMPERATURE-AIR', 'TuleR_S20ET-POTENTIAL', 'TuleR_S20FLOW', 'TuleR_S20PRECIP-INC', 'TuleR_S20SATURATION FRACTION', 'TuleR_S20STORAGE-SOIL', 'TuleR_S20SWE-OBSERVED', 'TuleR_S20TEMPERATURE-AIR']
# 2024-09-29 14:05:51,985: target_variables: ['ReservoirInflowFLOW-OBSERVED']
# 2024-09-29 14:05:51,986: number_of_basins: 1
# 2024-09-29 14:05:51,986: train_dir: /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test94_0.5_90_2909_140551/train_data
# 2024-09-29 14:05:51,986: img_log_dir: /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test94_0.5_90_2909_140551/img_log
# 2024-09-29 14:05:51,988: ### Device cpu will be used for training
# 2024-09-29 14:05:51,988: Loading basin data into xarray data set.
# 100%|██████████| 1/1 [00:00<00:00, 13.44it/s]
# 2024-09-29 14:05:52,084: Create lookup table and convert to pytorch tensor
# 100%|██████████| 1/1 [00:00<00:00, 17.07it/s]
# # Epoch 1: 100%|██████████| 23/23 [00:02<00:00,  8.00it/s, Loss: 0.1221]
# 2024-09-29 14:05:55,091: Epoch 1 average loss: avg_loss: 0.26600, avg_total_loss: 0.26600
# # Epoch 2: 100%|██████████| 23/23 [00:02<00:00,  7.96it/s, Loss: 0.0558]
# 2024-09-29 14:05:58,074: Epoch 2 average loss: avg_loss: 0.12479, avg_total_loss: 0.12479
# # Epoch 3: 100%|██████████| 23/23 [00:02<00:00,  7.91it/s, Loss: 0.0292]
# 2024-09-29 14:06:01,091: Epoch 3 average loss: avg_loss: 0.09510, avg_total_loss: 0.09510
# # Epoch 4: 100%|██████████| 23/23 [00:02<00:00,  7.86it/s, Loss: 0.0873]
# 2024-09-29 14:06:04,029: Epoch 4 average loss: avg_loss: 0.08857, avg_total_loss: 0.08857
# # Epoch 5: 100%|██████████| 23/23 [00:02<00:00,  7.78it/s, Loss: 0.0553]
# 2024-09-29 14:06:07,055: Epoch 5 average loss: avg_loss: 0.08471, avg_total_loss: 0.08471
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  3.55it/s]
# 2024-09-29 14:06:07,717: Epoch 5 average validation loss: 0.05498 -- Median validation metrics: avg_loss: 0.05498, NSE: 0.87516, MSE: 25890.85352
# 2024-09-29 14:06:07,741: Using the model weights from /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test94_0.5_90_2909_140551/model_epoch005.pt
# # Evaluation: 100%|██████████| 1/1 [00:00<00:00,  2.80it/s]
# 2024-09-29 14:06:08,110: Stored metrics at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test94_0.5_90_2909_140551/test/model_epoch005/test_metrics.csv
# 2024-09-29 14:06:08,112: Stored results at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test94_0.5_90_2909_140551/test/model_epoch005/test_results.p
# 2024-09-29 14:06:08,128: Using the model weights from /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test94_0.5_90_2909_140551/model_epoch005.pt
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  3.95it/s]
# 2024-09-29 14:06:08,389: Stored metrics at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test94_0.5_90_2909_140551/validation/model_epoch005/validation_metrics.csv
# 2024-09-29 14:06:08,392: Stored results at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test94_0.5_90_2909_140551/validation/model_epoch005/validation_results.p
# Elapsed time: 444.64401602745056 seconds

# %%
all_nse
# Out:
# [((63, 0.5, 90), 0.595575600862503),
#  ((64, 0.5, 90), 0.5938922166824341),
#  ((65, 0.5, 90), 0.5654114782810211),
#  ((66, 0.5, 90), 0.6782033443450928)]

# %%
# 1 run wiht 1 worker 25
# 2 run wiht 1 worker 150
#56 with 24 workers


# 2 runs with 2 ensemble members with 1 epoch: 152 seconds 
# 1 runs with 2 ensemble members with 1 epoch: 12 seconds

# %%
ipp.__version__
# Out:
# '8.8.0'

# %%
param_combos
# Out:
# [(66, 0.5, 90), (68, 0.5, 90)]
