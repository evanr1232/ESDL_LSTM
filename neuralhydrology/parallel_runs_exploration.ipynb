# %%
import os
import ipyparallel as ipp
import time
import pickle


from neuralhydrology.utils.config import Config

from neuralhydrology.nh_run import ESDL_start_run, eval_run
from pathlib import Path
import xarray as xr
from neuralhydrology.utils.nh_results_ensemble import create_results_ensemble

# %%
os.getcwd()
# Out:
# '/global/home/groups/pc_dsdisc/ESDL/ESDL_LSTM/neuralhydrology'

# %%
mycluster = ipp.Cluster(n=int(os.getenv('SLURM_CPUS_ON_NODE')))
c = mycluster.start_and_connect_sync()
dview = c[:]
dview.block = True   
dview.apply(lambda : "Hello, World")
# Out:
# Starting 32 engines with <class 'ipyparallel.cluster.launcher.LocalEngineSetLauncher'>
# 100%|██████████| 32/32 [00:05<00:00,  5.56engine/s]
# ['Hello, World',
#  'Hello, World',
#  'Hello, World',
#  'Hello, World',
#  'Hello, World',
#  'Hello, World',
#  'Hello, World',
#  'Hello, World',
#  'Hello, World',
#  'Hello, World',
#  'Hello, World',
#  'Hello, World',
#  'Hello, World',
#  'Hello, World',
#  'Hello, World',
#  'Hello, World',
#  'Hello, World',
#  'Hello, World',
#  'Hello, World',
#  'Hello, World',
#  'Hello, World',
#  'Hello, World',
#  'Hello, World',
#  'Hello, World',
#  'Hello, World',
#  'Hello, World',
#  'Hello, World',
#  'Hello, World',
#  'Hello, World',
#  'Hello, World',
#  'Hello, World',
#  'Hello, World']

# %%
len(c.ids)
# Out:
# 32

# %%
# hidden_states = [64, 96, 156, 196, 256]
# dropout_rate = [0.0, 0.25, 0.4, 0.5]
# input_seq_lengths = [90, 180, 270, 365]
#stacked_layers = [1, 2]

hidden_states = range(63, 63+len(c.ids))
dropout_rate = [0.5]
input_seq_lengths = [90]


param_combos = []
for i in hidden_states:
    for j in dropout_rate:
        for k in input_seq_lengths:
            param_combos.append((i, j, k))

# %%
len(param_combos)
# Out:
# 32

# %%
def ESDL_ensemble(params):
    '''Train ensemble for given config file and return ensemble NSE'''
    num_ensemble_members=1
    
    #copy data 24 times, each worker calls a different one
    
    config_path = Path("../initial_exploration/parallel_grid_search.yml") #read this in once, pass in object to all workers
    config = Config(config_path)
    config.update_config({'epochs': 15})
    config.update_config({'hidden_size': params[0]})
    config.update_config({'output_dropout': params[1]})
    config.update_config({'seq_length': params[2]})
    
    output_path = 'parallel_grid_search_test' + str(params[0]) + '_' + str(params[1]) + '_' + str(params[2])
    config.update_config({'experiment_name': output_path})
    
    #train num_ensemble_members models
    paths = [] #store the path of the results of the model
    for i in range(num_ensemble_members):
        ESDL_start_run(config, gpu=-1)
        path = config.run_dir
        paths.append(path)
    
    #evaluate models
    for p in paths:
        eval_run(run_dir=p, period="test")
        eval_run(run_dir=p, period="validation")
        with open(p / "test" / "model_epoch015" / "test_results.p", "rb") as fp: #comment next three lines out when using more than one ensemble member
            results = pickle.load(fp)
            ensemble_nse = results['Tuler']['1D']['NSE'] 

    # ensemble_run = create_results_ensemble(paths, period='validation')
    # ensemble_nse = ensemble_run['Tuler']['1D']['NSE']
    return (params, ensemble_nse)

# %%
# push imports to workers

dview.execute('from neuralhydrology.utils.config import Config')
dview.execute('from neuralhydrology.nh_run import ESDL_start_run, eval_run')
dview.execute('from neuralhydrology.nh_run import ESDL_start_run, eval_run')
dview.execute('from pathlib import Path')
dview.execute('import xarray as xr')
dview.execute('from neuralhydrology.utils.nh_results_ensemble import create_results_ensemble')
dview.execute('import pickle')
# Out:
# <AsyncResult(execute): finished>

# %%
lview = c.load_balanced_view()
# Cause execution on main process to wait while tasks sent to workers finish
lview.block = True

# %%
# in parallel

start_time = time.time()

all_nse = lview.map(ESDL_ensemble, param_combos) # map each param combo to the ESDL_ensemble fn, where they run in parallel
end_time = time.time()

elapsed_time = end_time - start_time
print("Elapsed time:", elapsed_time, "seconds")
# Out:
# Elapsed time: 97.69913697242737 seconds

# %%
len(all_nse)
# Out:
# 32

# %%
#in series
all_nse = []
start_time = time.time()

for i in param_combos:
    all_nse.append(ESDL_ensemble(i))

end_time = time.time()
elapsed_time = end_time - start_time
print("Elapsed time:", elapsed_time, "seconds")
# Out:
# 2024-09-29 14:10:08,046: Logging to /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test63_0.5_90_2909_141008/output.log initialized.
# 2024-09-29 14:10:08,047: ### Folder structure created at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test63_0.5_90_2909_141008
# 2024-09-29 14:10:08,047: ### Run configurations for parallel_grid_search_test63_0.5_90
# 2024-09-29 14:10:08,048: data_dir: /global/scratch/users/evanrobert
# 2024-09-29 14:10:08,048: experiment_name: parallel_grid_search_test63_0.5_90
# 2024-09-29 14:10:08,048: run_dir: /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test63_0.5_90_2909_141008
# 2024-09-29 14:10:08,048: train_basin_file: ../initial_exploration/exploration_tuler
# 2024-09-29 14:10:08,049: validation_basin_file: ../initial_exploration/exploration_tuler
# 2024-09-29 14:10:08,049: test_basin_file: ../initial_exploration/exploration_tuler
# 2024-09-29 14:10:08,050: train_start_date: 1981-10-01 00:00:00
# 2024-09-29 14:10:08,050: train_end_date: 1997-09-30 00:00:00
# 2024-09-29 14:10:08,050: validation_start_date: 1997-10-01 00:00:00
# 2024-09-29 14:10:08,051: validation_end_date: 2000-09-30 00:00:00
# 2024-09-29 14:10:08,051: test_start_date: 2000-10-01 00:00:00
# 2024-09-29 14:10:08,051: test_end_date: 2005-09-30 00:00:00
# 2024-09-29 14:10:08,051: device: cpu
# 2024-09-29 14:10:08,052: validate_every: 5
# 2024-09-29 14:10:08,052: validate_n_random_basins: 1
# 2024-09-29 14:10:08,052: metrics: ['NSE', 'MSE']
# 2024-09-29 14:10:08,053: model: cudalstm
# 2024-09-29 14:10:08,053: head: regression
# 2024-09-29 14:10:08,053: output_activation: linear
# 2024-09-29 14:10:08,053: hidden_size: 63
# 2024-09-29 14:10:08,054: initial_forget_bias: 3
# 2024-09-29 14:10:08,054: output_dropout: 0.5
# 2024-09-29 14:10:08,054: optimizer: Adam
# 2024-09-29 14:10:08,055: loss: MSE
# 2024-09-29 14:10:08,055: learning_rate: {0: 0.01, 30: 0.005, 40: 0.001}
# 2024-09-29 14:10:08,055: batch_size: 256
# 2024-09-29 14:10:08,055: epochs: 5
# 2024-09-29 14:10:08,056: clip_gradient_norm: 1
# 2024-09-29 14:10:08,056: predict_last_n: 1
# 2024-09-29 14:10:08,056: seq_length: 90
# 2024-09-29 14:10:08,056: num_workers: 1
# 2024-09-29 14:10:08,057: log_interval: 5
# 2024-09-29 14:10:08,057: log_tensorboard: True
# 2024-09-29 14:10:08,057: log_n_figures: 1
# 2024-09-29 14:10:08,057: save_weights_every: 1
# 2024-09-29 14:10:08,058: dataset: usace
# 2024-09-29 14:10:08,058: dynamic_inputs: ['MF_TuleR_S10ET-POTENTIAL', 'MF_TuleR_S10FLOW', 'MF_TuleR_S10PRECIP-INC', 'MF_TuleR_S10SATURATION FRACTION', 'MF_TuleR_S10STORAGE-SOIL', 'MF_TuleR_S10SWE-OBSERVED', 'MF_TuleR_S10TEMPERATURE-AIR', 'MF_TuleR_S20ET-POTENTIAL', 'MF_TuleR_S20FLOW', 'MF_TuleR_S20PRECIP-INC', 'MF_TuleR_S20SATURATION FRACTION', 'MF_TuleR_S20STORAGE-SOIL', 'MF_TuleR_S20SWE-OBSERVED', 'MF_TuleR_S20TEMPERATURE-AIR', 'NF_TuleR_S10ET-POTENTIAL', 'NF_TuleR_S10FLOW', 'NF_TuleR_S10PRECIP-INC', 'NF_TuleR_S10SATURATION FRACTION', 'NF_TuleR_S10STORAGE-SOIL', 'NF_TuleR_S10SWE-OBSERVED', 'NF_TuleR_S10TEMPERATURE-AIR', 'ReservoirInflowFLOW', 'SF_TuleR_S10ET-POTENTIAL', 'SF_TuleR_S10FLOW', 'SF_TuleR_S10PRECIP-INC', 'SF_TuleR_S10SATURATION FRACTION', 'SF_TuleR_S10STORAGE-SOIL', 'SF_TuleR_S10SWE-OBSERVED', 'SF_TuleR_S10TEMPERATURE-AIR', 'TuleR_S10ET-POTENTIAL', 'TuleR_S10FLOW', 'TuleR_S10PRECIP-INC', 'TuleR_S10SATURATION FRACTION', 'TuleR_S10STORAGE-SOIL', 'TuleR_S10TEMPERATURE-AIR', 'TuleR_S20ET-POTENTIAL', 'TuleR_S20FLOW', 'TuleR_S20PRECIP-INC', 'TuleR_S20SATURATION FRACTION', 'TuleR_S20STORAGE-SOIL', 'TuleR_S20SWE-OBSERVED', 'TuleR_S20TEMPERATURE-AIR']
# 2024-09-29 14:10:08,058: target_variables: ['ReservoirInflowFLOW-OBSERVED']
# 2024-09-29 14:10:08,059: number_of_basins: 1
# 2024-09-29 14:10:08,059: train_dir: /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test63_0.5_90_2909_141008/train_data
# 2024-09-29 14:10:08,059: img_log_dir: /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test63_0.5_90_2909_141008/img_log
# 2024-09-29 14:10:08,141: ### Device cpu will be used for training
# 2024-09-29 14:10:08,169: Loading basin data into xarray data set.
# 100%|██████████| 1/1 [00:00<00:00, 10.62it/s]
# 2024-09-29 14:10:08,291: Create lookup table and convert to pytorch tensor
# 100%|██████████| 1/1 [00:01<00:00,  1.77s/it]
# # Epoch 1: 100%|██████████| 23/23 [00:02<00:00, 10.27it/s, Loss: 0.1075]
# 2024-09-29 14:10:13,241: Epoch 1 average loss: avg_loss: 0.24811, avg_total_loss: 0.24811
# # Epoch 2: 100%|██████████| 23/23 [00:02<00:00, 11.26it/s, Loss: 0.1048]
# 2024-09-29 14:10:15,299: Epoch 2 average loss: avg_loss: 0.13788, avg_total_loss: 0.13788
# # Epoch 3: 100%|██████████| 23/23 [00:01<00:00, 11.71it/s, Loss: 0.0392]
# 2024-09-29 14:10:17,317: Epoch 3 average loss: avg_loss: 0.10233, avg_total_loss: 0.10233
# # Epoch 4: 100%|██████████| 23/23 [00:01<00:00, 11.71it/s, Loss: 0.0364]
# 2024-09-29 14:10:19,383: Epoch 4 average loss: avg_loss: 0.09796, avg_total_loss: 0.09796
# # Epoch 5: 100%|██████████| 23/23 [00:01<00:00, 11.73it/s, Loss: 0.0972]
# 2024-09-29 14:10:21,502: Epoch 5 average loss: avg_loss: 0.08778, avg_total_loss: 0.08778
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  1.44it/s]
# 2024-09-29 14:10:22,585: Epoch 5 average validation loss: 0.05050 -- Median validation metrics: avg_loss: 0.05050, NSE: 0.88489, MSE: 23872.40625
# 2024-09-29 14:10:22,608: Using the model weights from /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test63_0.5_90_2909_141008/model_epoch005.pt
# # Evaluation: 100%|██████████| 1/1 [00:00<00:00,  3.89it/s]
# 2024-09-29 14:10:22,875: Stored metrics at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test63_0.5_90_2909_141008/test/model_epoch005/test_metrics.csv
# 2024-09-29 14:10:22,878: Stored results at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test63_0.5_90_2909_141008/test/model_epoch005/test_results.p
# 2024-09-29 14:10:22,896: Using the model weights from /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test63_0.5_90_2909_141008/model_epoch005.pt
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  4.66it/s]
# 2024-09-29 14:10:23,118: Stored metrics at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test63_0.5_90_2909_141008/validation/model_epoch005/validation_metrics.csv
# 2024-09-29 14:10:23,121: Stored results at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test63_0.5_90_2909_141008/validation/model_epoch005/validation_results.p
# 2024-09-29 14:10:23,129: Logging to /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test64_0.5_90_2909_141023/output.log initialized.
# 2024-09-29 14:10:23,130: ### Folder structure created at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test64_0.5_90_2909_141023
# 2024-09-29 14:10:23,130: ### Run configurations for parallel_grid_search_test64_0.5_90
# 2024-09-29 14:10:23,131: data_dir: /global/scratch/users/evanrobert
# 2024-09-29 14:10:23,131: experiment_name: parallel_grid_search_test64_0.5_90
# 2024-09-29 14:10:23,131: run_dir: /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test64_0.5_90_2909_141023
# 2024-09-29 14:10:23,132: train_basin_file: ../initial_exploration/exploration_tuler
# 2024-09-29 14:10:23,132: validation_basin_file: ../initial_exploration/exploration_tuler
# 2024-09-29 14:10:23,132: test_basin_file: ../initial_exploration/exploration_tuler
# 2024-09-29 14:10:23,132: train_start_date: 1981-10-01 00:00:00
# 2024-09-29 14:10:23,133: train_end_date: 1997-09-30 00:00:00
# 2024-09-29 14:10:23,133: validation_start_date: 1997-10-01 00:00:00
# 2024-09-29 14:10:23,133: validation_end_date: 2000-09-30 00:00:00
# 2024-09-29 14:10:23,134: test_start_date: 2000-10-01 00:00:00
# 2024-09-29 14:10:23,134: test_end_date: 2005-09-30 00:00:00
# 2024-09-29 14:10:23,134: device: cpu
# 2024-09-29 14:10:23,134: validate_every: 5
# 2024-09-29 14:10:23,135: validate_n_random_basins: 1
# 2024-09-29 14:10:23,135: metrics: ['NSE', 'MSE']
# 2024-09-29 14:10:23,135: model: cudalstm
# 2024-09-29 14:10:23,135: head: regression
# 2024-09-29 14:10:23,136: output_activation: linear
# 2024-09-29 14:10:23,136: hidden_size: 64
# 2024-09-29 14:10:23,136: initial_forget_bias: 3
# 2024-09-29 14:10:23,137: output_dropout: 0.5
# 2024-09-29 14:10:23,137: optimizer: Adam
# 2024-09-29 14:10:23,137: loss: MSE
# 2024-09-29 14:10:23,137: learning_rate: {0: 0.01, 30: 0.005, 40: 0.001}
# 2024-09-29 14:10:23,138: batch_size: 256
# 2024-09-29 14:10:23,138: epochs: 5
# 2024-09-29 14:10:23,138: clip_gradient_norm: 1
# 2024-09-29 14:10:23,139: predict_last_n: 1
# 2024-09-29 14:10:23,139: seq_length: 90
# 2024-09-29 14:10:23,139: num_workers: 1
# 2024-09-29 14:10:23,139: log_interval: 5
# 2024-09-29 14:10:23,140: log_tensorboard: True
# 2024-09-29 14:10:23,140: log_n_figures: 1
# 2024-09-29 14:10:23,140: save_weights_every: 1
# 2024-09-29 14:10:23,140: dataset: usace
# 2024-09-29 14:10:23,141: dynamic_inputs: ['MF_TuleR_S10ET-POTENTIAL', 'MF_TuleR_S10FLOW', 'MF_TuleR_S10PRECIP-INC', 'MF_TuleR_S10SATURATION FRACTION', 'MF_TuleR_S10STORAGE-SOIL', 'MF_TuleR_S10SWE-OBSERVED', 'MF_TuleR_S10TEMPERATURE-AIR', 'MF_TuleR_S20ET-POTENTIAL', 'MF_TuleR_S20FLOW', 'MF_TuleR_S20PRECIP-INC', 'MF_TuleR_S20SATURATION FRACTION', 'MF_TuleR_S20STORAGE-SOIL', 'MF_TuleR_S20SWE-OBSERVED', 'MF_TuleR_S20TEMPERATURE-AIR', 'NF_TuleR_S10ET-POTENTIAL', 'NF_TuleR_S10FLOW', 'NF_TuleR_S10PRECIP-INC', 'NF_TuleR_S10SATURATION FRACTION', 'NF_TuleR_S10STORAGE-SOIL', 'NF_TuleR_S10SWE-OBSERVED', 'NF_TuleR_S10TEMPERATURE-AIR', 'ReservoirInflowFLOW', 'SF_TuleR_S10ET-POTENTIAL', 'SF_TuleR_S10FLOW', 'SF_TuleR_S10PRECIP-INC', 'SF_TuleR_S10SATURATION FRACTION', 'SF_TuleR_S10STORAGE-SOIL', 'SF_TuleR_S10SWE-OBSERVED', 'SF_TuleR_S10TEMPERATURE-AIR', 'TuleR_S10ET-POTENTIAL', 'TuleR_S10FLOW', 'TuleR_S10PRECIP-INC', 'TuleR_S10SATURATION FRACTION', 'TuleR_S10STORAGE-SOIL', 'TuleR_S10TEMPERATURE-AIR', 'TuleR_S20ET-POTENTIAL', 'TuleR_S20FLOW', 'TuleR_S20PRECIP-INC', 'TuleR_S20SATURATION FRACTION', 'TuleR_S20STORAGE-SOIL', 'TuleR_S20SWE-OBSERVED', 'TuleR_S20TEMPERATURE-AIR']
# 2024-09-29 14:10:23,141: target_variables: ['ReservoirInflowFLOW-OBSERVED']
# 2024-09-29 14:10:23,141: number_of_basins: 1
# 2024-09-29 14:10:23,141: train_dir: /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test64_0.5_90_2909_141023/train_data
# 2024-09-29 14:10:23,142: img_log_dir: /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test64_0.5_90_2909_141023/img_log
# 2024-09-29 14:10:23,145: ### Device cpu will be used for training
# 2024-09-29 14:10:23,145: Loading basin data into xarray data set.
# 100%|██████████| 1/1 [00:00<00:00, 13.40it/s]
# 2024-09-29 14:10:23,240: Create lookup table and convert to pytorch tensor
# 100%|██████████| 1/1 [00:00<00:00, 17.46it/s]
# # Epoch 1: 100%|██████████| 23/23 [00:01<00:00, 12.34it/s, Loss: 0.0661]
# 2024-09-29 14:10:25,227: Epoch 1 average loss: avg_loss: 0.24959, avg_total_loss: 0.24959
# # Epoch 2: 100%|██████████| 23/23 [00:01<00:00, 12.54it/s, Loss: 0.0544]
# 2024-09-29 14:10:27,117: Epoch 2 average loss: avg_loss: 0.13417, avg_total_loss: 0.13417
# # Epoch 3: 100%|██████████| 23/23 [00:01<00:00, 12.41it/s, Loss: 0.0450]
# 2024-09-29 14:10:29,015: Epoch 3 average loss: avg_loss: 0.10721, avg_total_loss: 0.10721
# # Epoch 4: 100%|██████████| 23/23 [00:01<00:00, 11.78it/s, Loss: 0.0711]
# 2024-09-29 14:10:31,023: Epoch 4 average loss: avg_loss: 0.09820, avg_total_loss: 0.09820
# # Epoch 5: 100%|██████████| 23/23 [00:01<00:00, 12.57it/s, Loss: 0.0286]
# 2024-09-29 14:10:32,888: Epoch 5 average loss: avg_loss: 0.09132, avg_total_loss: 0.09132
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  5.27it/s]
# 2024-09-29 14:10:33,445: Epoch 5 average validation loss: 0.04748 -- Median validation metrics: avg_loss: 0.04748, NSE: 0.89219, MSE: 22359.74414
# 2024-09-29 14:10:33,468: Using the model weights from /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test64_0.5_90_2909_141023/model_epoch005.pt
# # Evaluation: 100%|██████████| 1/1 [00:00<00:00,  4.12it/s]
# 2024-09-29 14:10:33,719: Stored metrics at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test64_0.5_90_2909_141023/test/model_epoch005/test_metrics.csv
# 2024-09-29 14:10:33,722: Stored results at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test64_0.5_90_2909_141023/test/model_epoch005/test_results.p
# 2024-09-29 14:10:33,738: Using the model weights from /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test64_0.5_90_2909_141023/model_epoch005.pt
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  5.40it/s]
# 2024-09-29 14:10:33,932: Stored metrics at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test64_0.5_90_2909_141023/validation/model_epoch005/validation_metrics.csv
# 2024-09-29 14:10:33,936: Stored results at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test64_0.5_90_2909_141023/validation/model_epoch005/validation_results.p
# 2024-09-29 14:10:33,943: Logging to /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test65_0.5_90_2909_141033/output.log initialized.
# 2024-09-29 14:10:33,944: ### Folder structure created at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test65_0.5_90_2909_141033
# 2024-09-29 14:10:33,944: ### Run configurations for parallel_grid_search_test65_0.5_90
# 2024-09-29 14:10:33,945: data_dir: /global/scratch/users/evanrobert
# 2024-09-29 14:10:33,945: experiment_name: parallel_grid_search_test65_0.5_90
# 2024-09-29 14:10:33,945: run_dir: /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test65_0.5_90_2909_141033
# 2024-09-29 14:10:33,946: train_basin_file: ../initial_exploration/exploration_tuler
# 2024-09-29 14:10:33,946: validation_basin_file: ../initial_exploration/exploration_tuler
# 2024-09-29 14:10:33,946: test_basin_file: ../initial_exploration/exploration_tuler
# 2024-09-29 14:10:33,947: train_start_date: 1981-10-01 00:00:00
# 2024-09-29 14:10:33,947: train_end_date: 1997-09-30 00:00:00
# 2024-09-29 14:10:33,947: validation_start_date: 1997-10-01 00:00:00
# 2024-09-29 14:10:33,948: validation_end_date: 2000-09-30 00:00:00
# 2024-09-29 14:10:33,948: test_start_date: 2000-10-01 00:00:00
# 2024-09-29 14:10:33,948: test_end_date: 2005-09-30 00:00:00
# 2024-09-29 14:10:33,948: device: cpu
# 2024-09-29 14:10:33,949: validate_every: 5
# 2024-09-29 14:10:33,949: validate_n_random_basins: 1
# 2024-09-29 14:10:33,949: metrics: ['NSE', 'MSE']
# 2024-09-29 14:10:33,950: model: cudalstm
# 2024-09-29 14:10:33,950: head: regression
# 2024-09-29 14:10:33,950: output_activation: linear
# 2024-09-29 14:10:33,950: hidden_size: 65
# 2024-09-29 14:10:33,951: initial_forget_bias: 3
# 2024-09-29 14:10:33,951: output_dropout: 0.5
# 2024-09-29 14:10:33,951: optimizer: Adam
# 2024-09-29 14:10:33,951: loss: MSE
# 2024-09-29 14:10:33,952: learning_rate: {0: 0.01, 30: 0.005, 40: 0.001}
# 2024-09-29 14:10:33,952: batch_size: 256
# 2024-09-29 14:10:33,952: epochs: 5
# 2024-09-29 14:10:33,953: clip_gradient_norm: 1
# 2024-09-29 14:10:33,953: predict_last_n: 1
# 2024-09-29 14:10:33,953: seq_length: 90
# 2024-09-29 14:10:33,953: num_workers: 1
# 2024-09-29 14:10:33,954: log_interval: 5
# 2024-09-29 14:10:33,954: log_tensorboard: True
# 2024-09-29 14:10:33,954: log_n_figures: 1
# 2024-09-29 14:10:33,955: save_weights_every: 1
# 2024-09-29 14:10:33,955: dataset: usace
# 2024-09-29 14:10:33,955: dynamic_inputs: ['MF_TuleR_S10ET-POTENTIAL', 'MF_TuleR_S10FLOW', 'MF_TuleR_S10PRECIP-INC', 'MF_TuleR_S10SATURATION FRACTION', 'MF_TuleR_S10STORAGE-SOIL', 'MF_TuleR_S10SWE-OBSERVED', 'MF_TuleR_S10TEMPERATURE-AIR', 'MF_TuleR_S20ET-POTENTIAL', 'MF_TuleR_S20FLOW', 'MF_TuleR_S20PRECIP-INC', 'MF_TuleR_S20SATURATION FRACTION', 'MF_TuleR_S20STORAGE-SOIL', 'MF_TuleR_S20SWE-OBSERVED', 'MF_TuleR_S20TEMPERATURE-AIR', 'NF_TuleR_S10ET-POTENTIAL', 'NF_TuleR_S10FLOW', 'NF_TuleR_S10PRECIP-INC', 'NF_TuleR_S10SATURATION FRACTION', 'NF_TuleR_S10STORAGE-SOIL', 'NF_TuleR_S10SWE-OBSERVED', 'NF_TuleR_S10TEMPERATURE-AIR', 'ReservoirInflowFLOW', 'SF_TuleR_S10ET-POTENTIAL', 'SF_TuleR_S10FLOW', 'SF_TuleR_S10PRECIP-INC', 'SF_TuleR_S10SATURATION FRACTION', 'SF_TuleR_S10STORAGE-SOIL', 'SF_TuleR_S10SWE-OBSERVED', 'SF_TuleR_S10TEMPERATURE-AIR', 'TuleR_S10ET-POTENTIAL', 'TuleR_S10FLOW', 'TuleR_S10PRECIP-INC', 'TuleR_S10SATURATION FRACTION', 'TuleR_S10STORAGE-SOIL', 'TuleR_S10TEMPERATURE-AIR', 'TuleR_S20ET-POTENTIAL', 'TuleR_S20FLOW', 'TuleR_S20PRECIP-INC', 'TuleR_S20SATURATION FRACTION', 'TuleR_S20STORAGE-SOIL', 'TuleR_S20SWE-OBSERVED', 'TuleR_S20TEMPERATURE-AIR']
# 2024-09-29 14:10:33,955: target_variables: ['ReservoirInflowFLOW-OBSERVED']
# 2024-09-29 14:10:33,955: number_of_basins: 1
# 2024-09-29 14:10:33,956: train_dir: /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test65_0.5_90_2909_141033/train_data
# 2024-09-29 14:10:33,956: img_log_dir: /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test65_0.5_90_2909_141033/img_log
# 2024-09-29 14:10:33,958: ### Device cpu will be used for training
# 2024-09-29 14:10:33,958: Loading basin data into xarray data set.
# 100%|██████████| 1/1 [00:00<00:00, 13.24it/s]
# 2024-09-29 14:10:34,054: Create lookup table and convert to pytorch tensor
# 100%|██████████| 1/1 [00:00<00:00, 16.71it/s]
# # Epoch 1: 100%|██████████| 23/23 [00:02<00:00, 11.50it/s, Loss: 0.1028]
# 2024-09-29 14:10:36,184: Epoch 1 average loss: avg_loss: 0.25286, avg_total_loss: 0.25286
# # Epoch 2: 100%|██████████| 23/23 [00:01<00:00, 11.70it/s, Loss: 0.0391]
# 2024-09-29 14:10:38,245: Epoch 2 average loss: avg_loss: 0.13805, avg_total_loss: 0.13805
# # Epoch 3: 100%|██████████| 23/23 [00:01<00:00, 11.65it/s, Loss: 0.1285]
# 2024-09-29 14:10:40,315: Epoch 3 average loss: avg_loss: 0.10744, avg_total_loss: 0.10744
# # Epoch 4: 100%|██████████| 23/23 [00:02<00:00, 11.50it/s, Loss: 0.0482]
# 2024-09-29 14:10:42,371: Epoch 4 average loss: avg_loss: 0.09230, avg_total_loss: 0.09230
# # Epoch 5: 100%|██████████| 23/23 [00:01<00:00, 11.69it/s, Loss: 0.1807]
# 2024-09-29 14:10:44,432: Epoch 5 average loss: avg_loss: 0.08029, avg_total_loss: 0.08029
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  4.48it/s]
# 2024-09-29 14:10:45,028: Epoch 5 average validation loss: 0.04857 -- Median validation metrics: avg_loss: 0.04857, NSE: 0.88920, MSE: 22979.33789
# 2024-09-29 14:10:45,053: Using the model weights from /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test65_0.5_90_2909_141033/model_epoch005.pt
# # Evaluation: 100%|██████████| 1/1 [00:00<00:00,  3.39it/s]
# 2024-09-29 14:10:45,359: Stored metrics at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test65_0.5_90_2909_141033/test/model_epoch005/test_metrics.csv
# 2024-09-29 14:10:45,366: Stored results at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test65_0.5_90_2909_141033/test/model_epoch005/test_results.p
# 2024-09-29 14:10:45,383: Using the model weights from /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test65_0.5_90_2909_141033/model_epoch005.pt
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  4.48it/s]
# 2024-09-29 14:10:45,613: Stored metrics at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test65_0.5_90_2909_141033/validation/model_epoch005/validation_metrics.csv
# 2024-09-29 14:10:45,616: Stored results at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test65_0.5_90_2909_141033/validation/model_epoch005/validation_results.p
# 2024-09-29 14:10:45,624: Logging to /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test66_0.5_90_2909_141045/output.log initialized.
# 2024-09-29 14:10:45,625: ### Folder structure created at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test66_0.5_90_2909_141045
# 2024-09-29 14:10:45,625: ### Run configurations for parallel_grid_search_test66_0.5_90
# 2024-09-29 14:10:45,626: data_dir: /global/scratch/users/evanrobert
# 2024-09-29 14:10:45,626: experiment_name: parallel_grid_search_test66_0.5_90
# 2024-09-29 14:10:45,626: run_dir: /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test66_0.5_90_2909_141045
# 2024-09-29 14:10:45,627: train_basin_file: ../initial_exploration/exploration_tuler
# 2024-09-29 14:10:45,627: validation_basin_file: ../initial_exploration/exploration_tuler
# 2024-09-29 14:10:45,627: test_basin_file: ../initial_exploration/exploration_tuler
# 2024-09-29 14:10:45,628: train_start_date: 1981-10-01 00:00:00
# 2024-09-29 14:10:45,628: train_end_date: 1997-09-30 00:00:00
# 2024-09-29 14:10:45,628: validation_start_date: 1997-10-01 00:00:00
# 2024-09-29 14:10:45,628: validation_end_date: 2000-09-30 00:00:00
# 2024-09-29 14:10:45,629: test_start_date: 2000-10-01 00:00:00
# 2024-09-29 14:10:45,629: test_end_date: 2005-09-30 00:00:00
# 2024-09-29 14:10:45,630: device: cpu
# 2024-09-29 14:10:45,630: validate_every: 5
# 2024-09-29 14:10:45,630: validate_n_random_basins: 1
# 2024-09-29 14:10:45,630: metrics: ['NSE', 'MSE']
# 2024-09-29 14:10:45,631: model: cudalstm
# 2024-09-29 14:10:45,631: head: regression
# 2024-09-29 14:10:45,631: output_activation: linear
# 2024-09-29 14:10:45,632: hidden_size: 66
# 2024-09-29 14:10:45,632: initial_forget_bias: 3
# 2024-09-29 14:10:45,632: output_dropout: 0.5
# 2024-09-29 14:10:45,632: optimizer: Adam
# 2024-09-29 14:10:45,633: loss: MSE
# 2024-09-29 14:10:45,633: learning_rate: {0: 0.01, 30: 0.005, 40: 0.001}
# 2024-09-29 14:10:45,633: batch_size: 256
# 2024-09-29 14:10:45,633: epochs: 5
# 2024-09-29 14:10:45,634: clip_gradient_norm: 1
# 2024-09-29 14:10:45,634: predict_last_n: 1
# 2024-09-29 14:10:45,634: seq_length: 90
# 2024-09-29 14:10:45,634: num_workers: 1
# 2024-09-29 14:10:45,634: log_interval: 5
# 2024-09-29 14:10:45,635: log_tensorboard: True
# 2024-09-29 14:10:45,635: log_n_figures: 1
# 2024-09-29 14:10:45,635: save_weights_every: 1
# 2024-09-29 14:10:45,635: dataset: usace
# 2024-09-29 14:10:45,636: dynamic_inputs: ['MF_TuleR_S10ET-POTENTIAL', 'MF_TuleR_S10FLOW', 'MF_TuleR_S10PRECIP-INC', 'MF_TuleR_S10SATURATION FRACTION', 'MF_TuleR_S10STORAGE-SOIL', 'MF_TuleR_S10SWE-OBSERVED', 'MF_TuleR_S10TEMPERATURE-AIR', 'MF_TuleR_S20ET-POTENTIAL', 'MF_TuleR_S20FLOW', 'MF_TuleR_S20PRECIP-INC', 'MF_TuleR_S20SATURATION FRACTION', 'MF_TuleR_S20STORAGE-SOIL', 'MF_TuleR_S20SWE-OBSERVED', 'MF_TuleR_S20TEMPERATURE-AIR', 'NF_TuleR_S10ET-POTENTIAL', 'NF_TuleR_S10FLOW', 'NF_TuleR_S10PRECIP-INC', 'NF_TuleR_S10SATURATION FRACTION', 'NF_TuleR_S10STORAGE-SOIL', 'NF_TuleR_S10SWE-OBSERVED', 'NF_TuleR_S10TEMPERATURE-AIR', 'ReservoirInflowFLOW', 'SF_TuleR_S10ET-POTENTIAL', 'SF_TuleR_S10FLOW', 'SF_TuleR_S10PRECIP-INC', 'SF_TuleR_S10SATURATION FRACTION', 'SF_TuleR_S10STORAGE-SOIL', 'SF_TuleR_S10SWE-OBSERVED', 'SF_TuleR_S10TEMPERATURE-AIR', 'TuleR_S10ET-POTENTIAL', 'TuleR_S10FLOW', 'TuleR_S10PRECIP-INC', 'TuleR_S10SATURATION FRACTION', 'TuleR_S10STORAGE-SOIL', 'TuleR_S10TEMPERATURE-AIR', 'TuleR_S20ET-POTENTIAL', 'TuleR_S20FLOW', 'TuleR_S20PRECIP-INC', 'TuleR_S20SATURATION FRACTION', 'TuleR_S20STORAGE-SOIL', 'TuleR_S20SWE-OBSERVED', 'TuleR_S20TEMPERATURE-AIR']
# 2024-09-29 14:10:45,637: target_variables: ['ReservoirInflowFLOW-OBSERVED']
# 2024-09-29 14:10:45,637: number_of_basins: 1
# 2024-09-29 14:10:45,637: train_dir: /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test66_0.5_90_2909_141045/train_data
# 2024-09-29 14:10:45,638: img_log_dir: /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test66_0.5_90_2909_141045/img_log
# 2024-09-29 14:10:45,639: ### Device cpu will be used for training
# 2024-09-29 14:10:45,640: Loading basin data into xarray data set.
# 100%|██████████| 1/1 [00:00<00:00, 12.19it/s]
# 2024-09-29 14:10:45,743: Create lookup table and convert to pytorch tensor
# 100%|██████████| 1/1 [00:00<00:00, 16.69it/s]
# # Epoch 1: 100%|██████████| 23/23 [00:02<00:00, 11.20it/s, Loss: 0.0615]
# 2024-09-29 14:10:47,925: Epoch 1 average loss: avg_loss: 0.25693, avg_total_loss: 0.25693
# # Epoch 2: 100%|██████████| 23/23 [00:02<00:00, 11.00it/s, Loss: 0.0457]
# 2024-09-29 14:10:50,089: Epoch 2 average loss: avg_loss: 0.13466, avg_total_loss: 0.13466
# # Epoch 3: 100%|██████████| 23/23 [00:02<00:00, 11.43it/s, Loss: 0.0377]
# 2024-09-29 14:10:52,211: Epoch 3 average loss: avg_loss: 0.09554, avg_total_loss: 0.09554
# # Epoch 4: 100%|██████████| 23/23 [00:02<00:00, 11.20it/s, Loss: 0.9081]
# 2024-09-29 14:10:54,304: Epoch 4 average loss: avg_loss: 0.11343, avg_total_loss: 0.11343
# # Epoch 5: 100%|██████████| 23/23 [00:02<00:00, 11.37it/s, Loss: 0.0536]
# 2024-09-29 14:10:56,512: Epoch 5 average loss: avg_loss: 0.09531, avg_total_loss: 0.09531
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  4.51it/s]
# 2024-09-29 14:10:57,178: Epoch 5 average validation loss: 0.05033 -- Median validation metrics: avg_loss: 0.05033, NSE: 0.88545, MSE: 23756.51562
# 2024-09-29 14:10:57,203: Using the model weights from /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test66_0.5_90_2909_141045/model_epoch005.pt
# # Evaluation: 100%|██████████| 1/1 [00:00<00:00,  3.49it/s]
# 2024-09-29 14:10:57,498: Stored metrics at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test66_0.5_90_2909_141045/test/model_epoch005/test_metrics.csv
# 2024-09-29 14:10:57,500: Stored results at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test66_0.5_90_2909_141045/test/model_epoch005/test_results.p
# 2024-09-29 14:10:57,518: Using the model weights from /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test66_0.5_90_2909_141045/model_epoch005.pt
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  4.81it/s]
# 2024-09-29 14:10:57,733: Stored metrics at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test66_0.5_90_2909_141045/validation/model_epoch005/validation_metrics.csv
# 2024-09-29 14:10:57,736: Stored results at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test66_0.5_90_2909_141045/validation/model_epoch005/validation_results.p
# 2024-09-29 14:10:57,745: Logging to /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test67_0.5_90_2909_141057/output.log initialized.
# 2024-09-29 14:10:57,745: ### Folder structure created at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test67_0.5_90_2909_141057
# 2024-09-29 14:10:57,746: ### Run configurations for parallel_grid_search_test67_0.5_90
# 2024-09-29 14:10:57,746: data_dir: /global/scratch/users/evanrobert
# 2024-09-29 14:10:57,746: experiment_name: parallel_grid_search_test67_0.5_90
# 2024-09-29 14:10:57,746: run_dir: /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test67_0.5_90_2909_141057
# 2024-09-29 14:10:57,747: train_basin_file: ../initial_exploration/exploration_tuler
# 2024-09-29 14:10:57,747: validation_basin_file: ../initial_exploration/exploration_tuler
# 2024-09-29 14:10:57,747: test_basin_file: ../initial_exploration/exploration_tuler
# 2024-09-29 14:10:57,748: train_start_date: 1981-10-01 00:00:00
# 2024-09-29 14:10:57,748: train_end_date: 1997-09-30 00:00:00
# 2024-09-29 14:10:57,748: validation_start_date: 1997-10-01 00:00:00
# 2024-09-29 14:10:57,749: validation_end_date: 2000-09-30 00:00:00
# 2024-09-29 14:10:57,749: test_start_date: 2000-10-01 00:00:00
# 2024-09-29 14:10:57,749: test_end_date: 2005-09-30 00:00:00
# 2024-09-29 14:10:57,749: device: cpu
# 2024-09-29 14:10:57,750: validate_every: 5
# 2024-09-29 14:10:57,750: validate_n_random_basins: 1
# 2024-09-29 14:10:57,750: metrics: ['NSE', 'MSE']
# 2024-09-29 14:10:57,751: model: cudalstm
# 2024-09-29 14:10:57,751: head: regression
# 2024-09-29 14:10:57,751: output_activation: linear
# 2024-09-29 14:10:57,752: hidden_size: 67
# 2024-09-29 14:10:57,752: initial_forget_bias: 3
# 2024-09-29 14:10:57,752: output_dropout: 0.5
# 2024-09-29 14:10:57,752: optimizer: Adam
# 2024-09-29 14:10:57,753: loss: MSE
# 2024-09-29 14:10:57,753: learning_rate: {0: 0.01, 30: 0.005, 40: 0.001}
# 2024-09-29 14:10:57,753: batch_size: 256
# 2024-09-29 14:10:57,753: epochs: 5
# 2024-09-29 14:10:57,754: clip_gradient_norm: 1
# 2024-09-29 14:10:57,754: predict_last_n: 1
# 2024-09-29 14:10:57,754: seq_length: 90
# 2024-09-29 14:10:57,754: num_workers: 1
# 2024-09-29 14:10:57,755: log_interval: 5
# 2024-09-29 14:10:57,755: log_tensorboard: True
# 2024-09-29 14:10:57,755: log_n_figures: 1
# 2024-09-29 14:10:57,755: save_weights_every: 1
# 2024-09-29 14:10:57,756: dataset: usace
# 2024-09-29 14:10:57,756: dynamic_inputs: ['MF_TuleR_S10ET-POTENTIAL', 'MF_TuleR_S10FLOW', 'MF_TuleR_S10PRECIP-INC', 'MF_TuleR_S10SATURATION FRACTION', 'MF_TuleR_S10STORAGE-SOIL', 'MF_TuleR_S10SWE-OBSERVED', 'MF_TuleR_S10TEMPERATURE-AIR', 'MF_TuleR_S20ET-POTENTIAL', 'MF_TuleR_S20FLOW', 'MF_TuleR_S20PRECIP-INC', 'MF_TuleR_S20SATURATION FRACTION', 'MF_TuleR_S20STORAGE-SOIL', 'MF_TuleR_S20SWE-OBSERVED', 'MF_TuleR_S20TEMPERATURE-AIR', 'NF_TuleR_S10ET-POTENTIAL', 'NF_TuleR_S10FLOW', 'NF_TuleR_S10PRECIP-INC', 'NF_TuleR_S10SATURATION FRACTION', 'NF_TuleR_S10STORAGE-SOIL', 'NF_TuleR_S10SWE-OBSERVED', 'NF_TuleR_S10TEMPERATURE-AIR', 'ReservoirInflowFLOW', 'SF_TuleR_S10ET-POTENTIAL', 'SF_TuleR_S10FLOW', 'SF_TuleR_S10PRECIP-INC', 'SF_TuleR_S10SATURATION FRACTION', 'SF_TuleR_S10STORAGE-SOIL', 'SF_TuleR_S10SWE-OBSERVED', 'SF_TuleR_S10TEMPERATURE-AIR', 'TuleR_S10ET-POTENTIAL', 'TuleR_S10FLOW', 'TuleR_S10PRECIP-INC', 'TuleR_S10SATURATION FRACTION', 'TuleR_S10STORAGE-SOIL', 'TuleR_S10TEMPERATURE-AIR', 'TuleR_S20ET-POTENTIAL', 'TuleR_S20FLOW', 'TuleR_S20PRECIP-INC', 'TuleR_S20SATURATION FRACTION', 'TuleR_S20STORAGE-SOIL', 'TuleR_S20SWE-OBSERVED', 'TuleR_S20TEMPERATURE-AIR']
# 2024-09-29 14:10:57,756: target_variables: ['ReservoirInflowFLOW-OBSERVED']
# 2024-09-29 14:10:57,757: number_of_basins: 1
# 2024-09-29 14:10:57,757: train_dir: /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test67_0.5_90_2909_141057/train_data
# 2024-09-29 14:10:57,757: img_log_dir: /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test67_0.5_90_2909_141057/img_log
# 2024-09-29 14:10:57,759: ### Device cpu will be used for training
# 2024-09-29 14:10:57,759: Loading basin data into xarray data set.
# 100%|██████████| 1/1 [00:00<00:00, 12.28it/s]
# 2024-09-29 14:10:57,861: Create lookup table and convert to pytorch tensor
# 100%|██████████| 1/1 [00:00<00:00, 17.27it/s]
# # Epoch 1: 100%|██████████| 23/23 [00:02<00:00, 11.08it/s, Loss: 0.0660]
# 2024-09-29 14:11:00,065: Epoch 1 average loss: avg_loss: 0.26104, avg_total_loss: 0.26104
# # Epoch 2: 100%|██████████| 23/23 [00:02<00:00, 10.93it/s, Loss: 0.0306]
# 2024-09-29 14:11:02,280: Epoch 2 average loss: avg_loss: 0.13220, avg_total_loss: 0.13220
# # Epoch 3: 100%|██████████| 23/23 [00:02<00:00, 11.24it/s, Loss: 0.0727]
# 2024-09-29 14:11:04,348: Epoch 3 average loss: avg_loss: 0.10495, avg_total_loss: 0.10495
# # Epoch 4: 100%|██████████| 23/23 [00:02<00:00, 11.26it/s, Loss: 0.0160]
# 2024-09-29 14:11:06,481: Epoch 4 average loss: avg_loss: 0.09116, avg_total_loss: 0.09116
# # Epoch 5: 100%|██████████| 23/23 [00:02<00:00, 11.22it/s, Loss: 0.2395]
# 2024-09-29 14:11:08,612: Epoch 5 average loss: avg_loss: 0.10317, avg_total_loss: 0.10317
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  4.55it/s]
# 2024-09-29 14:11:09,266: Epoch 5 average validation loss: 0.05374 -- Median validation metrics: avg_loss: 0.05374, NSE: 0.87813, MSE: 25276.10938
# 2024-09-29 14:11:09,290: Using the model weights from /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test67_0.5_90_2909_141057/model_epoch005.pt
# # Evaluation: 100%|██████████| 1/1 [00:00<00:00,  3.47it/s]
# 2024-09-29 14:11:09,586: Stored metrics at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test67_0.5_90_2909_141057/test/model_epoch005/test_metrics.csv
# 2024-09-29 14:11:09,589: Stored results at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test67_0.5_90_2909_141057/test/model_epoch005/test_results.p
# 2024-09-29 14:11:09,608: Using the model weights from /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test67_0.5_90_2909_141057/model_epoch005.pt
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  4.66it/s]
# 2024-09-29 14:11:09,835: Stored metrics at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test67_0.5_90_2909_141057/validation/model_epoch005/validation_metrics.csv
# 2024-09-29 14:11:09,838: Stored results at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test67_0.5_90_2909_141057/validation/model_epoch005/validation_results.p
# 2024-09-29 14:11:09,845: Logging to /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test68_0.5_90_2909_141109/output.log initialized.
# 2024-09-29 14:11:09,846: ### Folder structure created at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test68_0.5_90_2909_141109
# 2024-09-29 14:11:09,846: ### Run configurations for parallel_grid_search_test68_0.5_90
# 2024-09-29 14:11:09,847: data_dir: /global/scratch/users/evanrobert
# 2024-09-29 14:11:09,847: experiment_name: parallel_grid_search_test68_0.5_90
# 2024-09-29 14:11:09,847: run_dir: /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test68_0.5_90_2909_141109
# 2024-09-29 14:11:09,848: train_basin_file: ../initial_exploration/exploration_tuler
# 2024-09-29 14:11:09,848: validation_basin_file: ../initial_exploration/exploration_tuler
# 2024-09-29 14:11:09,848: test_basin_file: ../initial_exploration/exploration_tuler
# 2024-09-29 14:11:09,848: train_start_date: 1981-10-01 00:00:00
# 2024-09-29 14:11:09,849: train_end_date: 1997-09-30 00:00:00
# 2024-09-29 14:11:09,849: validation_start_date: 1997-10-01 00:00:00
# 2024-09-29 14:11:09,849: validation_end_date: 2000-09-30 00:00:00
# 2024-09-29 14:11:09,850: test_start_date: 2000-10-01 00:00:00
# 2024-09-29 14:11:09,850: test_end_date: 2005-09-30 00:00:00
# 2024-09-29 14:11:09,850: device: cpu
# 2024-09-29 14:11:09,851: validate_every: 5
# 2024-09-29 14:11:09,851: validate_n_random_basins: 1
# 2024-09-29 14:11:09,851: metrics: ['NSE', 'MSE']
# 2024-09-29 14:11:09,851: model: cudalstm
# 2024-09-29 14:11:09,851: head: regression
# 2024-09-29 14:11:09,852: output_activation: linear
# 2024-09-29 14:11:09,852: hidden_size: 68
# 2024-09-29 14:11:09,852: initial_forget_bias: 3
# 2024-09-29 14:11:09,853: output_dropout: 0.5
# 2024-09-29 14:11:09,853: optimizer: Adam
# 2024-09-29 14:11:09,853: loss: MSE
# 2024-09-29 14:11:09,853: learning_rate: {0: 0.01, 30: 0.005, 40: 0.001}
# 2024-09-29 14:11:09,854: batch_size: 256
# 2024-09-29 14:11:09,854: epochs: 5
# 2024-09-29 14:11:09,854: clip_gradient_norm: 1
# 2024-09-29 14:11:09,854: predict_last_n: 1
# 2024-09-29 14:11:09,855: seq_length: 90
# 2024-09-29 14:11:09,855: num_workers: 1
# 2024-09-29 14:11:09,855: log_interval: 5
# 2024-09-29 14:11:09,856: log_tensorboard: True
# 2024-09-29 14:11:09,856: log_n_figures: 1
# 2024-09-29 14:11:09,856: save_weights_every: 1
# 2024-09-29 14:11:09,856: dataset: usace
# 2024-09-29 14:11:09,857: dynamic_inputs: ['MF_TuleR_S10ET-POTENTIAL', 'MF_TuleR_S10FLOW', 'MF_TuleR_S10PRECIP-INC', 'MF_TuleR_S10SATURATION FRACTION', 'MF_TuleR_S10STORAGE-SOIL', 'MF_TuleR_S10SWE-OBSERVED', 'MF_TuleR_S10TEMPERATURE-AIR', 'MF_TuleR_S20ET-POTENTIAL', 'MF_TuleR_S20FLOW', 'MF_TuleR_S20PRECIP-INC', 'MF_TuleR_S20SATURATION FRACTION', 'MF_TuleR_S20STORAGE-SOIL', 'MF_TuleR_S20SWE-OBSERVED', 'MF_TuleR_S20TEMPERATURE-AIR', 'NF_TuleR_S10ET-POTENTIAL', 'NF_TuleR_S10FLOW', 'NF_TuleR_S10PRECIP-INC', 'NF_TuleR_S10SATURATION FRACTION', 'NF_TuleR_S10STORAGE-SOIL', 'NF_TuleR_S10SWE-OBSERVED', 'NF_TuleR_S10TEMPERATURE-AIR', 'ReservoirInflowFLOW', 'SF_TuleR_S10ET-POTENTIAL', 'SF_TuleR_S10FLOW', 'SF_TuleR_S10PRECIP-INC', 'SF_TuleR_S10SATURATION FRACTION', 'SF_TuleR_S10STORAGE-SOIL', 'SF_TuleR_S10SWE-OBSERVED', 'SF_TuleR_S10TEMPERATURE-AIR', 'TuleR_S10ET-POTENTIAL', 'TuleR_S10FLOW', 'TuleR_S10PRECIP-INC', 'TuleR_S10SATURATION FRACTION', 'TuleR_S10STORAGE-SOIL', 'TuleR_S10TEMPERATURE-AIR', 'TuleR_S20ET-POTENTIAL', 'TuleR_S20FLOW', 'TuleR_S20PRECIP-INC', 'TuleR_S20SATURATION FRACTION', 'TuleR_S20STORAGE-SOIL', 'TuleR_S20SWE-OBSERVED', 'TuleR_S20TEMPERATURE-AIR']
# 2024-09-29 14:11:09,857: target_variables: ['ReservoirInflowFLOW-OBSERVED']
# 2024-09-29 14:11:09,857: number_of_basins: 1
# 2024-09-29 14:11:09,858: train_dir: /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test68_0.5_90_2909_141109/train_data
# 2024-09-29 14:11:09,858: img_log_dir: /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test68_0.5_90_2909_141109/img_log
# 2024-09-29 14:11:09,860: ### Device cpu will be used for training
# 2024-09-29 14:11:09,861: Loading basin data into xarray data set.
# 100%|██████████| 1/1 [00:00<00:00, 12.34it/s]
# 2024-09-29 14:11:09,962: Create lookup table and convert to pytorch tensor
# 100%|██████████| 1/1 [00:00<00:00, 17.21it/s]
# # Epoch 1: 100%|██████████| 23/23 [00:02<00:00, 10.39it/s, Loss: 0.0625]
# 2024-09-29 14:11:12,490: Epoch 1 average loss: avg_loss: 0.25102, avg_total_loss: 0.25102
# # Epoch 2: 100%|██████████| 23/23 [00:02<00:00, 11.31it/s, Loss: 0.0427]
# 2024-09-29 14:11:14,693: Epoch 2 average loss: avg_loss: 0.13337, avg_total_loss: 0.13337
# # Epoch 3: 100%|██████████| 23/23 [00:01<00:00, 11.61it/s, Loss: 0.0572]
# 2024-09-29 14:11:16,763: Epoch 3 average loss: avg_loss: 0.11080, avg_total_loss: 0.11080
# # Epoch 4: 100%|██████████| 23/23 [00:02<00:00, 11.20it/s, Loss: 0.0496]
# 2024-09-29 14:11:18,912: Epoch 4 average loss: avg_loss: 0.09189, avg_total_loss: 0.09189
# # Epoch 5: 100%|██████████| 23/23 [00:02<00:00, 11.31it/s, Loss: 0.0760]
# 2024-09-29 14:11:21,073: Epoch 5 average loss: avg_loss: 0.09033, avg_total_loss: 0.09033
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  4.51it/s]
# 2024-09-29 14:11:21,651: Epoch 5 average validation loss: 0.05405 -- Median validation metrics: avg_loss: 0.05405, NSE: 0.87749, MSE: 25407.51562
# 2024-09-29 14:11:21,673: Using the model weights from /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test68_0.5_90_2909_141109/model_epoch005.pt
# # Evaluation: 100%|██████████| 1/1 [00:00<00:00,  3.48it/s]
# 2024-09-29 14:11:21,969: Stored metrics at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test68_0.5_90_2909_141109/test/model_epoch005/test_metrics.csv
# 2024-09-29 14:11:21,972: Stored results at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test68_0.5_90_2909_141109/test/model_epoch005/test_results.p
# 2024-09-29 14:11:21,990: Using the model weights from /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test68_0.5_90_2909_141109/model_epoch005.pt
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  4.82it/s]
# 2024-09-29 14:11:22,205: Stored metrics at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test68_0.5_90_2909_141109/validation/model_epoch005/validation_metrics.csv
# 2024-09-29 14:11:22,208: Stored results at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test68_0.5_90_2909_141109/validation/model_epoch005/validation_results.p
# 2024-09-29 14:11:22,216: Logging to /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test69_0.5_90_2909_141122/output.log initialized.
# 2024-09-29 14:11:22,217: ### Folder structure created at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test69_0.5_90_2909_141122
# 2024-09-29 14:11:22,217: ### Run configurations for parallel_grid_search_test69_0.5_90
# 2024-09-29 14:11:22,218: data_dir: /global/scratch/users/evanrobert
# 2024-09-29 14:11:22,218: experiment_name: parallel_grid_search_test69_0.5_90
# 2024-09-29 14:11:22,218: run_dir: /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test69_0.5_90_2909_141122
# 2024-09-29 14:11:22,219: train_basin_file: ../initial_exploration/exploration_tuler
# 2024-09-29 14:11:22,219: validation_basin_file: ../initial_exploration/exploration_tuler
# 2024-09-29 14:11:22,219: test_basin_file: ../initial_exploration/exploration_tuler
# 2024-09-29 14:11:22,219: train_start_date: 1981-10-01 00:00:00
# 2024-09-29 14:11:22,219: train_end_date: 1997-09-30 00:00:00
# 2024-09-29 14:11:22,220: validation_start_date: 1997-10-01 00:00:00
# 2024-09-29 14:11:22,220: validation_end_date: 2000-09-30 00:00:00
# 2024-09-29 14:11:22,221: test_start_date: 2000-10-01 00:00:00
# 2024-09-29 14:11:22,221: test_end_date: 2005-09-30 00:00:00
# 2024-09-29 14:11:22,221: device: cpu
# 2024-09-29 14:11:22,221: validate_every: 5
# 2024-09-29 14:11:22,222: validate_n_random_basins: 1
# 2024-09-29 14:11:22,222: metrics: ['NSE', 'MSE']
# 2024-09-29 14:11:22,222: model: cudalstm
# 2024-09-29 14:11:22,222: head: regression
# 2024-09-29 14:11:22,223: output_activation: linear
# 2024-09-29 14:11:22,223: hidden_size: 69
# 2024-09-29 14:11:22,223: initial_forget_bias: 3
# 2024-09-29 14:11:22,224: output_dropout: 0.5
# 2024-09-29 14:11:22,224: optimizer: Adam
# 2024-09-29 14:11:22,224: loss: MSE
# 2024-09-29 14:11:22,225: learning_rate: {0: 0.01, 30: 0.005, 40: 0.001}
# 2024-09-29 14:11:22,225: batch_size: 256
# 2024-09-29 14:11:22,225: epochs: 5
# 2024-09-29 14:11:22,226: clip_gradient_norm: 1
# 2024-09-29 14:11:22,226: predict_last_n: 1
# 2024-09-29 14:11:22,226: seq_length: 90
# 2024-09-29 14:11:22,226: num_workers: 1
# 2024-09-29 14:11:22,227: log_interval: 5
# 2024-09-29 14:11:22,227: log_tensorboard: True
# 2024-09-29 14:11:22,227: log_n_figures: 1
# 2024-09-29 14:11:22,228: save_weights_every: 1
# 2024-09-29 14:11:22,228: dataset: usace
# 2024-09-29 14:11:22,228: dynamic_inputs: ['MF_TuleR_S10ET-POTENTIAL', 'MF_TuleR_S10FLOW', 'MF_TuleR_S10PRECIP-INC', 'MF_TuleR_S10SATURATION FRACTION', 'MF_TuleR_S10STORAGE-SOIL', 'MF_TuleR_S10SWE-OBSERVED', 'MF_TuleR_S10TEMPERATURE-AIR', 'MF_TuleR_S20ET-POTENTIAL', 'MF_TuleR_S20FLOW', 'MF_TuleR_S20PRECIP-INC', 'MF_TuleR_S20SATURATION FRACTION', 'MF_TuleR_S20STORAGE-SOIL', 'MF_TuleR_S20SWE-OBSERVED', 'MF_TuleR_S20TEMPERATURE-AIR', 'NF_TuleR_S10ET-POTENTIAL', 'NF_TuleR_S10FLOW', 'NF_TuleR_S10PRECIP-INC', 'NF_TuleR_S10SATURATION FRACTION', 'NF_TuleR_S10STORAGE-SOIL', 'NF_TuleR_S10SWE-OBSERVED', 'NF_TuleR_S10TEMPERATURE-AIR', 'ReservoirInflowFLOW', 'SF_TuleR_S10ET-POTENTIAL', 'SF_TuleR_S10FLOW', 'SF_TuleR_S10PRECIP-INC', 'SF_TuleR_S10SATURATION FRACTION', 'SF_TuleR_S10STORAGE-SOIL', 'SF_TuleR_S10SWE-OBSERVED', 'SF_TuleR_S10TEMPERATURE-AIR', 'TuleR_S10ET-POTENTIAL', 'TuleR_S10FLOW', 'TuleR_S10PRECIP-INC', 'TuleR_S10SATURATION FRACTION', 'TuleR_S10STORAGE-SOIL', 'TuleR_S10TEMPERATURE-AIR', 'TuleR_S20ET-POTENTIAL', 'TuleR_S20FLOW', 'TuleR_S20PRECIP-INC', 'TuleR_S20SATURATION FRACTION', 'TuleR_S20STORAGE-SOIL', 'TuleR_S20SWE-OBSERVED', 'TuleR_S20TEMPERATURE-AIR']
# 2024-09-29 14:11:22,229: target_variables: ['ReservoirInflowFLOW-OBSERVED']
# 2024-09-29 14:11:22,229: number_of_basins: 1
# 2024-09-29 14:11:22,229: train_dir: /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test69_0.5_90_2909_141122/train_data
# 2024-09-29 14:11:22,229: img_log_dir: /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test69_0.5_90_2909_141122/img_log
# 2024-09-29 14:11:22,232: ### Device cpu will be used for training
# 2024-09-29 14:11:22,232: Loading basin data into xarray data set.
# 100%|██████████| 1/1 [00:00<00:00, 13.09it/s]
# 2024-09-29 14:11:22,330: Create lookup table and convert to pytorch tensor
# 100%|██████████| 1/1 [00:00<00:00, 17.48it/s]
# # Epoch 1: 100%|██████████| 23/23 [00:02<00:00, 10.63it/s, Loss: 0.1081]
# 2024-09-29 14:11:24,625: Epoch 1 average loss: avg_loss: 0.23344, avg_total_loss: 0.23344
# # Epoch 2: 100%|██████████| 23/23 [00:02<00:00, 10.70it/s, Loss: 0.0323]
# 2024-09-29 14:11:26,834: Epoch 2 average loss: avg_loss: 0.12969, avg_total_loss: 0.12969
# # Epoch 3: 100%|██████████| 23/23 [00:02<00:00, 11.07it/s, Loss: 0.0983]
# 2024-09-29 14:11:28,949: Epoch 3 average loss: avg_loss: 0.11006, avg_total_loss: 0.11006
# # Epoch 4: 100%|██████████| 23/23 [00:02<00:00, 10.42it/s, Loss: 0.1512]
# 2024-09-29 14:11:31,232: Epoch 4 average loss: avg_loss: 0.09548, avg_total_loss: 0.09548
# # Epoch 5: 100%|██████████| 23/23 [00:02<00:00, 10.68it/s, Loss: 0.0372]
# 2024-09-29 14:11:33,472: Epoch 5 average loss: avg_loss: 0.09272, avg_total_loss: 0.09272
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  4.47it/s]
# 2024-09-29 14:11:34,008: Epoch 5 average validation loss: 0.04797 -- Median validation metrics: avg_loss: 0.04797, NSE: 0.89091, MSE: 22625.72266
# 2024-09-29 14:11:34,034: Using the model weights from /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test69_0.5_90_2909_141122/model_epoch005.pt
# # Evaluation: 100%|██████████| 1/1 [00:00<00:00,  3.43it/s]
# 2024-09-29 14:11:34,335: Stored metrics at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test69_0.5_90_2909_141122/test/model_epoch005/test_metrics.csv
# 2024-09-29 14:11:34,339: Stored results at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test69_0.5_90_2909_141122/test/model_epoch005/test_results.p
# 2024-09-29 14:11:34,356: Using the model weights from /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test69_0.5_90_2909_141122/model_epoch005.pt
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  4.75it/s]
# 2024-09-29 14:11:34,576: Stored metrics at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test69_0.5_90_2909_141122/validation/model_epoch005/validation_metrics.csv
# 2024-09-29 14:11:34,578: Stored results at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test69_0.5_90_2909_141122/validation/model_epoch005/validation_results.p
# 2024-09-29 14:11:34,587: Logging to /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test70_0.5_90_2909_141134/output.log initialized.
# 2024-09-29 14:11:34,588: ### Folder structure created at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test70_0.5_90_2909_141134
# 2024-09-29 14:11:34,588: ### Run configurations for parallel_grid_search_test70_0.5_90
# 2024-09-29 14:11:34,588: data_dir: /global/scratch/users/evanrobert
# 2024-09-29 14:11:34,589: experiment_name: parallel_grid_search_test70_0.5_90
# 2024-09-29 14:11:34,589: run_dir: /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test70_0.5_90_2909_141134
# 2024-09-29 14:11:34,589: train_basin_file: ../initial_exploration/exploration_tuler
# 2024-09-29 14:11:34,590: validation_basin_file: ../initial_exploration/exploration_tuler
# 2024-09-29 14:11:34,590: test_basin_file: ../initial_exploration/exploration_tuler
# 2024-09-29 14:11:34,590: train_start_date: 1981-10-01 00:00:00
# 2024-09-29 14:11:34,591: train_end_date: 1997-09-30 00:00:00
# 2024-09-29 14:11:34,591: validation_start_date: 1997-10-01 00:00:00
# 2024-09-29 14:11:34,591: validation_end_date: 2000-09-30 00:00:00
# 2024-09-29 14:11:34,591: test_start_date: 2000-10-01 00:00:00
# 2024-09-29 14:11:34,592: test_end_date: 2005-09-30 00:00:00
# 2024-09-29 14:11:34,592: device: cpu
# 2024-09-29 14:11:34,592: validate_every: 5
# 2024-09-29 14:11:34,593: validate_n_random_basins: 1
# 2024-09-29 14:11:34,593: metrics: ['NSE', 'MSE']
# 2024-09-29 14:11:34,593: model: cudalstm
# 2024-09-29 14:11:34,593: head: regression
# 2024-09-29 14:11:34,594: output_activation: linear
# 2024-09-29 14:11:34,594: hidden_size: 70
# 2024-09-29 14:11:34,594: initial_forget_bias: 3
# 2024-09-29 14:11:34,594: output_dropout: 0.5
# 2024-09-29 14:11:34,595: optimizer: Adam
# 2024-09-29 14:11:34,595: loss: MSE
# 2024-09-29 14:11:34,595: learning_rate: {0: 0.01, 30: 0.005, 40: 0.001}
# 2024-09-29 14:11:34,595: batch_size: 256
# 2024-09-29 14:11:34,596: epochs: 5
# 2024-09-29 14:11:34,596: clip_gradient_norm: 1
# 2024-09-29 14:11:34,597: predict_last_n: 1
# 2024-09-29 14:11:34,597: seq_length: 90
# 2024-09-29 14:11:34,597: num_workers: 1
# 2024-09-29 14:11:34,598: log_interval: 5
# 2024-09-29 14:11:34,598: log_tensorboard: True
# 2024-09-29 14:11:34,598: log_n_figures: 1
# 2024-09-29 14:11:34,598: save_weights_every: 1
# 2024-09-29 14:11:34,599: dataset: usace
# ...
# 2024-09-29 14:16:51,984: target_variables: ['ReservoirInflowFLOW-OBSERVED']
# 2024-09-29 14:16:51,984: number_of_basins: 1
# 2024-09-29 14:16:51,984: train_dir: /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test92_0.5_90_2909_141651/train_data
# 2024-09-29 14:16:51,985: img_log_dir: /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test92_0.5_90_2909_141651/img_log
# 2024-09-29 14:16:51,986: ### Device cpu will be used for training
# 2024-09-29 14:16:51,987: Loading basin data into xarray data set.
# 100%|██████████| 1/1 [00:00<00:00, 12.88it/s]
# 2024-09-29 14:16:52,086: Create lookup table and convert to pytorch tensor
# 100%|██████████| 1/1 [00:00<00:00, 16.95it/s]
# # Epoch 1: 100%|██████████| 23/23 [00:02<00:00,  7.93it/s, Loss: 0.0528]
# 2024-09-29 14:16:55,117: Epoch 1 average loss: avg_loss: 0.24247, avg_total_loss: 0.24247
# # Epoch 2: 100%|██████████| 23/23 [00:02<00:00,  8.02it/s, Loss: 0.0528]
# 2024-09-29 14:16:58,078: Epoch 2 average loss: avg_loss: 0.12742, avg_total_loss: 0.12742
# # Epoch 3: 100%|██████████| 23/23 [00:02<00:00,  7.89it/s, Loss: 0.0394]
# 2024-09-29 14:17:01,086: Epoch 3 average loss: avg_loss: 0.10235, avg_total_loss: 0.10235
# # Epoch 4: 100%|██████████| 23/23 [00:02<00:00,  7.87it/s, Loss: 0.0354]
# 2024-09-29 14:17:04,132: Epoch 4 average loss: avg_loss: 0.09550, avg_total_loss: 0.09550
# # Epoch 5: 100%|██████████| 23/23 [00:02<00:00,  7.89it/s, Loss: 0.1192]
# 2024-09-29 14:17:07,092: Epoch 5 average loss: avg_loss: 0.08663, avg_total_loss: 0.08663
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  3.56it/s]
# 2024-09-29 14:17:07,741: Epoch 5 average validation loss: 0.05162 -- Median validation metrics: avg_loss: 0.05162, NSE: 0.88301, MSE: 24263.05664
# 2024-09-29 14:17:07,765: Using the model weights from /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test92_0.5_90_2909_141651/model_epoch005.pt
# # Evaluation: 100%|██████████| 1/1 [00:00<00:00,  2.81it/s]
# 2024-09-29 14:17:08,130: Stored metrics at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test92_0.5_90_2909_141651/test/model_epoch005/test_metrics.csv
# 2024-09-29 14:17:08,132: Stored results at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test92_0.5_90_2909_141651/test/model_epoch005/test_results.p
# 2024-09-29 14:17:08,150: Using the model weights from /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test92_0.5_90_2909_141651/model_epoch005.pt
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  3.93it/s]
# 2024-09-29 14:17:08,411: Stored metrics at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test92_0.5_90_2909_141651/validation/model_epoch005/validation_metrics.csv
# 2024-09-29 14:17:08,414: Stored results at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test92_0.5_90_2909_141651/validation/model_epoch005/validation_results.p
# 2024-09-29 14:17:08,422: Logging to /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test93_0.5_90_2909_141708/output.log initialized.
# 2024-09-29 14:17:08,422: ### Folder structure created at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test93_0.5_90_2909_141708
# 2024-09-29 14:17:08,423: ### Run configurations for parallel_grid_search_test93_0.5_90
# 2024-09-29 14:17:08,423: data_dir: /global/scratch/users/evanrobert
# 2024-09-29 14:17:08,423: experiment_name: parallel_grid_search_test93_0.5_90
# 2024-09-29 14:17:08,423: run_dir: /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test93_0.5_90_2909_141708
# 2024-09-29 14:17:08,424: train_basin_file: ../initial_exploration/exploration_tuler
# 2024-09-29 14:17:08,424: validation_basin_file: ../initial_exploration/exploration_tuler
# 2024-09-29 14:17:08,424: test_basin_file: ../initial_exploration/exploration_tuler
# 2024-09-29 14:17:08,425: train_start_date: 1981-10-01 00:00:00
# 2024-09-29 14:17:08,425: train_end_date: 1997-09-30 00:00:00
# 2024-09-29 14:17:08,425: validation_start_date: 1997-10-01 00:00:00
# 2024-09-29 14:17:08,426: validation_end_date: 2000-09-30 00:00:00
# 2024-09-29 14:17:08,426: test_start_date: 2000-10-01 00:00:00
# 2024-09-29 14:17:08,426: test_end_date: 2005-09-30 00:00:00
# 2024-09-29 14:17:08,426: device: cpu
# 2024-09-29 14:17:08,427: validate_every: 5
# 2024-09-29 14:17:08,427: validate_n_random_basins: 1
# 2024-09-29 14:17:08,427: metrics: ['NSE', 'MSE']
# 2024-09-29 14:17:08,428: model: cudalstm
# 2024-09-29 14:17:08,428: head: regression
# 2024-09-29 14:17:08,428: output_activation: linear
# 2024-09-29 14:17:08,428: hidden_size: 93
# 2024-09-29 14:17:08,428: initial_forget_bias: 3
# 2024-09-29 14:17:08,429: output_dropout: 0.5
# 2024-09-29 14:17:08,429: optimizer: Adam
# 2024-09-29 14:17:08,429: loss: MSE
# 2024-09-29 14:17:08,429: learning_rate: {0: 0.01, 30: 0.005, 40: 0.001}
# 2024-09-29 14:17:08,430: batch_size: 256
# 2024-09-29 14:17:08,430: epochs: 5
# 2024-09-29 14:17:08,431: clip_gradient_norm: 1
# 2024-09-29 14:17:08,431: predict_last_n: 1
# 2024-09-29 14:17:08,431: seq_length: 90
# 2024-09-29 14:17:08,431: num_workers: 1
# 2024-09-29 14:17:08,431: log_interval: 5
# 2024-09-29 14:17:08,432: log_tensorboard: True
# 2024-09-29 14:17:08,432: log_n_figures: 1
# 2024-09-29 14:17:08,432: save_weights_every: 1
# 2024-09-29 14:17:08,433: dataset: usace
# 2024-09-29 14:17:08,433: dynamic_inputs: ['MF_TuleR_S10ET-POTENTIAL', 'MF_TuleR_S10FLOW', 'MF_TuleR_S10PRECIP-INC', 'MF_TuleR_S10SATURATION FRACTION', 'MF_TuleR_S10STORAGE-SOIL', 'MF_TuleR_S10SWE-OBSERVED', 'MF_TuleR_S10TEMPERATURE-AIR', 'MF_TuleR_S20ET-POTENTIAL', 'MF_TuleR_S20FLOW', 'MF_TuleR_S20PRECIP-INC', 'MF_TuleR_S20SATURATION FRACTION', 'MF_TuleR_S20STORAGE-SOIL', 'MF_TuleR_S20SWE-OBSERVED', 'MF_TuleR_S20TEMPERATURE-AIR', 'NF_TuleR_S10ET-POTENTIAL', 'NF_TuleR_S10FLOW', 'NF_TuleR_S10PRECIP-INC', 'NF_TuleR_S10SATURATION FRACTION', 'NF_TuleR_S10STORAGE-SOIL', 'NF_TuleR_S10SWE-OBSERVED', 'NF_TuleR_S10TEMPERATURE-AIR', 'ReservoirInflowFLOW', 'SF_TuleR_S10ET-POTENTIAL', 'SF_TuleR_S10FLOW', 'SF_TuleR_S10PRECIP-INC', 'SF_TuleR_S10SATURATION FRACTION', 'SF_TuleR_S10STORAGE-SOIL', 'SF_TuleR_S10SWE-OBSERVED', 'SF_TuleR_S10TEMPERATURE-AIR', 'TuleR_S10ET-POTENTIAL', 'TuleR_S10FLOW', 'TuleR_S10PRECIP-INC', 'TuleR_S10SATURATION FRACTION', 'TuleR_S10STORAGE-SOIL', 'TuleR_S10TEMPERATURE-AIR', 'TuleR_S20ET-POTENTIAL', 'TuleR_S20FLOW', 'TuleR_S20PRECIP-INC', 'TuleR_S20SATURATION FRACTION', 'TuleR_S20STORAGE-SOIL', 'TuleR_S20SWE-OBSERVED', 'TuleR_S20TEMPERATURE-AIR']
# 2024-09-29 14:17:08,433: target_variables: ['ReservoirInflowFLOW-OBSERVED']
# 2024-09-29 14:17:08,433: number_of_basins: 1
# 2024-09-29 14:17:08,434: train_dir: /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test93_0.5_90_2909_141708/train_data
# 2024-09-29 14:17:08,434: img_log_dir: /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test93_0.5_90_2909_141708/img_log
# 2024-09-29 14:17:08,436: ### Device cpu will be used for training
# 2024-09-29 14:17:08,437: Loading basin data into xarray data set.
# 100%|██████████| 1/1 [00:00<00:00, 12.74it/s]
# 2024-09-29 14:17:08,536: Create lookup table and convert to pytorch tensor
# 100%|██████████| 1/1 [00:00<00:00, 16.65it/s]
# # Epoch 1: 100%|██████████| 23/23 [00:03<00:00,  7.35it/s, Loss: 0.0770]
# 2024-09-29 14:17:11,799: Epoch 1 average loss: avg_loss: 0.22608, avg_total_loss: 0.22608
# # Epoch 2: 100%|██████████| 23/23 [00:03<00:00,  7.58it/s, Loss: 0.0905]
# 2024-09-29 14:17:14,906: Epoch 2 average loss: avg_loss: 0.12734, avg_total_loss: 0.12734
# # Epoch 3: 100%|██████████| 23/23 [00:03<00:00,  7.65it/s, Loss: 0.0527]
# 2024-09-29 14:17:17,968: Epoch 3 average loss: avg_loss: 0.09815, avg_total_loss: 0.09815
# # Epoch 4: 100%|██████████| 23/23 [00:03<00:00,  7.55it/s, Loss: 0.0360]
# 2024-09-29 14:17:21,163: Epoch 4 average loss: avg_loss: 0.08380, avg_total_loss: 0.08380
# # Epoch 5: 100%|██████████| 23/23 [00:03<00:00,  7.53it/s, Loss: 0.0527]
# 2024-09-29 14:17:24,401: Epoch 5 average loss: avg_loss: 0.08130, avg_total_loss: 0.08130
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  3.55it/s]
# 2024-09-29 14:17:25,044: Epoch 5 average validation loss: 0.05327 -- Median validation metrics: avg_loss: 0.05327, NSE: 0.87854, MSE: 25189.32617
# 2024-09-29 14:17:25,071: Using the model weights from /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test93_0.5_90_2909_141708/model_epoch005.pt
# # Evaluation: 100%|██████████| 1/1 [00:00<00:00,  2.71it/s]
# 2024-09-29 14:17:25,450: Stored metrics at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test93_0.5_90_2909_141708/test/model_epoch005/test_metrics.csv
# 2024-09-29 14:17:25,453: Stored results at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test93_0.5_90_2909_141708/test/model_epoch005/test_results.p
# 2024-09-29 14:17:25,472: Using the model weights from /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test93_0.5_90_2909_141708/model_epoch005.pt
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  3.77it/s]
# 2024-09-29 14:17:25,746: Stored metrics at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test93_0.5_90_2909_141708/validation/model_epoch005/validation_metrics.csv
# 2024-09-29 14:17:25,748: Stored results at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test93_0.5_90_2909_141708/validation/model_epoch005/validation_results.p
# 2024-09-29 14:17:25,756: Logging to /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test94_0.5_90_2909_141725/output.log initialized.
# 2024-09-29 14:17:25,757: ### Folder structure created at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test94_0.5_90_2909_141725
# 2024-09-29 14:17:25,757: ### Run configurations for parallel_grid_search_test94_0.5_90
# 2024-09-29 14:17:25,757: data_dir: /global/scratch/users/evanrobert
# 2024-09-29 14:17:25,758: experiment_name: parallel_grid_search_test94_0.5_90
# 2024-09-29 14:17:25,758: run_dir: /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test94_0.5_90_2909_141725
# 2024-09-29 14:17:25,758: train_basin_file: ../initial_exploration/exploration_tuler
# 2024-09-29 14:17:25,758: validation_basin_file: ../initial_exploration/exploration_tuler
# 2024-09-29 14:17:25,759: test_basin_file: ../initial_exploration/exploration_tuler
# 2024-09-29 14:17:25,759: train_start_date: 1981-10-01 00:00:00
# 2024-09-29 14:17:25,759: train_end_date: 1997-09-30 00:00:00
# 2024-09-29 14:17:25,760: validation_start_date: 1997-10-01 00:00:00
# 2024-09-29 14:17:25,760: validation_end_date: 2000-09-30 00:00:00
# 2024-09-29 14:17:25,760: test_start_date: 2000-10-01 00:00:00
# 2024-09-29 14:17:25,761: test_end_date: 2005-09-30 00:00:00
# 2024-09-29 14:17:25,761: device: cpu
# 2024-09-29 14:17:25,761: validate_every: 5
# 2024-09-29 14:17:25,762: validate_n_random_basins: 1
# 2024-09-29 14:17:25,762: metrics: ['NSE', 'MSE']
# 2024-09-29 14:17:25,762: model: cudalstm
# 2024-09-29 14:17:25,762: head: regression
# 2024-09-29 14:17:25,763: output_activation: linear
# 2024-09-29 14:17:25,763: hidden_size: 94
# 2024-09-29 14:17:25,763: initial_forget_bias: 3
# 2024-09-29 14:17:25,763: output_dropout: 0.5
# 2024-09-29 14:17:25,764: optimizer: Adam
# 2024-09-29 14:17:25,764: loss: MSE
# 2024-09-29 14:17:25,764: learning_rate: {0: 0.01, 30: 0.005, 40: 0.001}
# 2024-09-29 14:17:25,765: batch_size: 256
# 2024-09-29 14:17:25,765: epochs: 5
# 2024-09-29 14:17:25,765: clip_gradient_norm: 1
# 2024-09-29 14:17:25,765: predict_last_n: 1
# 2024-09-29 14:17:25,766: seq_length: 90
# 2024-09-29 14:17:25,766: num_workers: 1
# 2024-09-29 14:17:25,766: log_interval: 5
# 2024-09-29 14:17:25,767: log_tensorboard: True
# 2024-09-29 14:17:25,767: log_n_figures: 1
# 2024-09-29 14:17:25,767: save_weights_every: 1
# 2024-09-29 14:17:25,768: dataset: usace
# 2024-09-29 14:17:25,768: dynamic_inputs: ['MF_TuleR_S10ET-POTENTIAL', 'MF_TuleR_S10FLOW', 'MF_TuleR_S10PRECIP-INC', 'MF_TuleR_S10SATURATION FRACTION', 'MF_TuleR_S10STORAGE-SOIL', 'MF_TuleR_S10SWE-OBSERVED', 'MF_TuleR_S10TEMPERATURE-AIR', 'MF_TuleR_S20ET-POTENTIAL', 'MF_TuleR_S20FLOW', 'MF_TuleR_S20PRECIP-INC', 'MF_TuleR_S20SATURATION FRACTION', 'MF_TuleR_S20STORAGE-SOIL', 'MF_TuleR_S20SWE-OBSERVED', 'MF_TuleR_S20TEMPERATURE-AIR', 'NF_TuleR_S10ET-POTENTIAL', 'NF_TuleR_S10FLOW', 'NF_TuleR_S10PRECIP-INC', 'NF_TuleR_S10SATURATION FRACTION', 'NF_TuleR_S10STORAGE-SOIL', 'NF_TuleR_S10SWE-OBSERVED', 'NF_TuleR_S10TEMPERATURE-AIR', 'ReservoirInflowFLOW', 'SF_TuleR_S10ET-POTENTIAL', 'SF_TuleR_S10FLOW', 'SF_TuleR_S10PRECIP-INC', 'SF_TuleR_S10SATURATION FRACTION', 'SF_TuleR_S10STORAGE-SOIL', 'SF_TuleR_S10SWE-OBSERVED', 'SF_TuleR_S10TEMPERATURE-AIR', 'TuleR_S10ET-POTENTIAL', 'TuleR_S10FLOW', 'TuleR_S10PRECIP-INC', 'TuleR_S10SATURATION FRACTION', 'TuleR_S10STORAGE-SOIL', 'TuleR_S10TEMPERATURE-AIR', 'TuleR_S20ET-POTENTIAL', 'TuleR_S20FLOW', 'TuleR_S20PRECIP-INC', 'TuleR_S20SATURATION FRACTION', 'TuleR_S20STORAGE-SOIL', 'TuleR_S20SWE-OBSERVED', 'TuleR_S20TEMPERATURE-AIR']
# 2024-09-29 14:17:25,768: target_variables: ['ReservoirInflowFLOW-OBSERVED']
# 2024-09-29 14:17:25,768: number_of_basins: 1
# 2024-09-29 14:17:25,769: train_dir: /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test94_0.5_90_2909_141725/train_data
# 2024-09-29 14:17:25,769: img_log_dir: /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test94_0.5_90_2909_141725/img_log
# 2024-09-29 14:17:25,771: ### Device cpu will be used for training
# 2024-09-29 14:17:25,772: Loading basin data into xarray data set.
# 100%|██████████| 1/1 [00:00<00:00, 12.64it/s]
# 2024-09-29 14:17:25,872: Create lookup table and convert to pytorch tensor
# 100%|██████████| 1/1 [00:00<00:00, 17.21it/s]
# # Epoch 1: 100%|██████████| 23/23 [00:02<00:00,  7.71it/s, Loss: 0.0647]
# 2024-09-29 14:17:28,985: Epoch 1 average loss: avg_loss: 0.24815, avg_total_loss: 0.24815
# # Epoch 2: 100%|██████████| 23/23 [00:02<00:00,  7.71it/s, Loss: 0.0274]
# 2024-09-29 14:17:32,056: Epoch 2 average loss: avg_loss: 0.12339, avg_total_loss: 0.12339
# # Epoch 3: 100%|██████████| 23/23 [00:02<00:00,  7.71it/s, Loss: 0.0951]
# 2024-09-29 14:17:35,097: Epoch 3 average loss: avg_loss: 0.09767, avg_total_loss: 0.09767
# # Epoch 4: 100%|██████████| 23/23 [00:02<00:00,  7.67it/s, Loss: 0.0589]
# 2024-09-29 14:17:38,134: Epoch 4 average loss: avg_loss: 0.08571, avg_total_loss: 0.08571
# # Epoch 5: 100%|██████████| 23/23 [00:03<00:00,  7.66it/s, Loss: 0.0433]
# 2024-09-29 14:17:41,228: Epoch 5 average loss: avg_loss: 0.07650, avg_total_loss: 0.07650
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  3.66it/s]
# 2024-09-29 14:17:42,069: Epoch 5 average validation loss: 0.06450 -- Median validation metrics: avg_loss: 0.06450, NSE: 0.85320, MSE: 30445.19336
# 2024-09-29 14:17:42,094: Using the model weights from /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test94_0.5_90_2909_141725/model_epoch005.pt
# # Evaluation: 100%|██████████| 1/1 [00:00<00:00,  2.79it/s]
# 2024-09-29 14:17:42,464: Stored metrics at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test94_0.5_90_2909_141725/test/model_epoch005/test_metrics.csv
# 2024-09-29 14:17:42,467: Stored results at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test94_0.5_90_2909_141725/test/model_epoch005/test_results.p
# 2024-09-29 14:17:42,484: Using the model weights from /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test94_0.5_90_2909_141725/model_epoch005.pt
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  4.00it/s]
# 2024-09-29 14:17:42,741: Stored metrics at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test94_0.5_90_2909_141725/validation/model_epoch005/validation_metrics.csv
# 2024-09-29 14:17:42,744: Stored results at /global/scratch/users/evanrobert/parallel_test/parallel_grid_search_test94_0.5_90_2909_141725/validation/model_epoch005/validation_results.p
# Elapsed time: 454.76357102394104 seconds

# %%
all_nse
# Out:
# [((63, 0.5, 90), 0.595575600862503),
#  ((64, 0.5, 90), 0.5938922166824341),
#  ((65, 0.5, 90), 0.5654114782810211),
#  ((66, 0.5, 90), 0.6782033443450928)]

# %%
# 1 run wiht 1 worker 25
# 2 run wiht 1 worker 150
#56 with 24 workers


# 2 runs with 2 ensemble members with 1 epoch: 152 seconds 
# 1 runs with 2 ensemble members with 1 epoch: 12 seconds

# %%
ipp.__version__
# Out:
# '8.8.0'

# %%
param_combos
# Out:
# [(66, 0.5, 90), (68, 0.5, 90)]
